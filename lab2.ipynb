# %%
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import lightgbm as lgbm
from sklearn.metrics import log_loss

# %%
def time2cov(time_):
    return time.strftime("%Y-%m-%d %H:%M:%S",time.localtime(time_))

# %%
def user_check(df, behaviour):
    user_day = df.groupby(['user_id', 'day', behaviour]).size().reset_index().rename(columns={0: 'user_id_query_day_{}'.format(behaviour)})
    df = pd.merge(df, user_day, how = 'left', on=['user_id', 'day',behaviour])
    user_day_hour = df.groupby(['user_id', 'day', 'hour', behaviour]).size().reset_index().rename(columns={0: 'user_id_query_day_hour_{}'.format(behaviour)})
    df = pd.merge(df, user_day_hour, how = 'left', on=['user_id', 'day', 'hour',behaviour])
    n = 0
    check_time_day = np.ones((len(df),1))
    num = {}
    bd = df.day.min()
    for u, i, d in zip(df.user_id, df[behaviour], df.day):
        n += 1
        try:
            num[(u,i)] += 1
        except:
            num[(u,i)] = 0
        check_time_day[n-1] = num[(u,i)]
        if d > bd:
            num = {}
        bd = d
    df['check_{}_time_day'.format(behaviour)] = check_time_day
    df['check_{}_ratio'.format(behaviour)] = df['check_{}_time_day'.format(behaviour)] / df['user_id_query_day_{}'.format(behaviour)]
    return df

# %%
def convert_time(df):
    df['hour'] = [int(datetime.datetime.fromtimestamp(i).strftime('%H')) for i in df.context_timestamp]
    df['day'] = [int(datetime.datetime.fromtimestamp(i).strftime('%d')) for i in df.context_timestamp]
    for f in ['user_id', 'item_id', 'shop_id', 'item_category_list', 'item_city_id', 'user_gender_id', 'user_age_level', 'user_occupation_id', 'item_brand_id']:
        user_query_day = df.groupby([f, 'day']).size().reset_index().rename(columns={0: '{}_query_day'.format(f)})
        df = pd.merge(df, user_query_day, how = 'left', on=[f, 'day'])
        query_day_hour = df.groupby([f, 'day', 'hour']).size().reset_index().rename(columns={0: '{}_query_day_hour'.format(f)})
        df = pd.merge(df, query_day_hour, 'left',on=[f, 'day', 'hour'])
    df['context_timestamp'] = df['context_timestamp'].apply(time2cov)
    df.sort_values(by='context_timestamp',inplace=True)

    for f in ['shop_id', 'item_brand_id', 'item_id', 'item_category_list', 'context_page_id','item_pv_level','item_sales_level','item_collected_level','item_price_level']:
        df = user_check(df, f)
    n = 0
    check_time_day = np.ones((len(df),1))
    num = {}
    bd = df.day.min()
    for u, d in zip(df.user_id, df.day):
        n += 1
        try:
            num[(u)] += 1
        except:
            num[(u)] = 0
        check_time_day[n-1] = num[(u)]
        if d > bd:
            num = {}
        bd = d
    df['check_time_day'] = check_time_day
    f1 = 'check_time_day'
    f2 = 'user_id_query_day'
    df['check_ratio_day_all'] = df[f1] / df[f2]
    return df

# %%
def run(features, label, df, clf,verbose = True):
    print(features[-1])
    X = df
    y = df[label]
    Loss = []
    T = X.context_timestamp <= '2018-09-23 23:59:59'
    X_train, X_test = X[T], X[~T]
    X_train, X_test = X_train[features], X_test[features]
    #norm = StandardScaler()
    #X_train = norm.fit_transform(X_train[features])
    #X_test = norm.transform(X_test[features])
    y_train, y_test = y[T], y[~T]
    clf.fit(X_train,y_train, eval_set = [(X_train, y_train), (X_test, y_test)], eval_metric='logloss', verbose=verbose,early_stopping_rounds=200)
    predict = clf.predict_proba(X_test)[:,1]
    logloss = log_loss(y_test, predict)
    print(logloss)
    return clf

# %%
df = pd.read_csv('data/train/round1_ijcai_18_train_20180301.txt',sep=' ')
df.context_timestamp += 8*60*60
df = convert_time(df)
item_category_list_unique = list(np.unique(df.item_category_list))
df.item_category_list.replace(item_category_list_unique, list(np.arange(len(item_category_list_unique))), inplace=True)
label = 'is_trade'

# %%
start_features = [
                  'item_category_list','item_city_id','item_price_level','item_sales_level','item_collected_level','item_pv_level',
                  'user_gender_id','user_age_level','user_occupation_id','user_star_level',
                  'context_page_id',
                  'shop_review_num_level','shop_review_positive_rate','shop_score_service','shop_score_delivery',
                  'hour','day',
                  'user_id_query_day_item_category_list','user_id_query_day_hour','user_id_query_day_hour_item_category_list',
                  'check_item_category_list_ratio','check_ratio_day_all','check_time_day','check_shop_id_ratio','check_item_brand_id_ratio',
                  'shop_id',
                  'item_id_query_day',
                  'user_id_query_day_item_brand_id','user_id_query_day_hour_item_brand_id','user_id_query_day_item_id',
                  #'check_item_pv_level_ratio','user_id_query_day_item_pv_level',
                  #'user_id_query_day_hour_item_pv_level', 'check_item_pv_level_time_day',
                 ]

clf = lgbm.LGBMClassifier(random_state=1, num_leaves = 6,
                          n_estimators=5000,max_depth=3,learning_rate = 0.08, n_jobs=30) #008154
clf = run(start_features, label, df, clf)
# Out:
# user_id_query_day_item_id
# [1]	training's binary_logloss: 0.622078	valid_1's binary_logloss: 0.621696
# Training until validation scores don't improve for 200 rounds.
# [2]	training's binary_logloss: 0.561537	valid_1's binary_logloss: 0.560798
# [3]	training's binary_logloss: 0.509396	valid_1's binary_logloss: 0.508335
# [4]	training's binary_logloss: 0.464102	valid_1's binary_logloss: 0.462742
# [5]	training's binary_logloss: 0.42448	valid_1's binary_logloss: 0.42284
# [6]	training's binary_logloss: 0.389621	valid_1's binary_logloss: 0.387714
# [7]	training's binary_logloss: 0.358807	valid_1's binary_logloss: 0.356642
# [8]	training's binary_logloss: 0.33146	valid_1's binary_logloss: 0.329053
# [9]	training's binary_logloss: 0.307112	valid_1's binary_logloss: 0.304476
# [10]	training's binary_logloss: 0.285373	valid_1's binary_logloss: 0.282521
# [11]	training's binary_logloss: 0.265917	valid_1's binary_logloss: 0.262849
# [12]	training's binary_logloss: 0.248472	valid_1's binary_logloss: 0.245188
# [13]	training's binary_logloss: 0.232801	valid_1's binary_logloss: 0.229317
# [14]	training's binary_logloss: 0.218708	valid_1's binary_logloss: 0.215029
# [15]	training's binary_logloss: 0.206019	valid_1's binary_logloss: 0.202144
# [16]	training's binary_logloss: 0.194582	valid_1's binary_logloss: 0.190523
# [17]	training's binary_logloss: 0.184266	valid_1's binary_logloss: 0.180033
# [18]	training's binary_logloss: 0.174959	valid_1's binary_logloss: 0.170551
# [19]	training's binary_logloss: 0.166558	valid_1's binary_logloss: 0.161979
# [20]	training's binary_logloss: 0.158969	valid_1's binary_logloss: 0.154224
# [21]	training's binary_logloss: 0.152117	valid_1's binary_logloss: 0.14721
# [22]	training's binary_logloss: 0.145929	valid_1's binary_logloss: 0.140864
# [23]	training's binary_logloss: 0.140337	valid_1's binary_logloss: 0.135132
# [24]	training's binary_logloss: 0.135293	valid_1's binary_logloss: 0.129936
# [25]	training's binary_logloss: 0.130735	valid_1's binary_logloss: 0.125242
# [26]	training's binary_logloss: 0.126627	valid_1's binary_logloss: 0.12099
# [27]	training's binary_logloss: 0.122918	valid_1's binary_logloss: 0.11716
# [28]	training's binary_logloss: 0.11958	valid_1's binary_logloss: 0.113687
# [29]	training's binary_logloss: 0.11657	valid_1's binary_logloss: 0.110559
# [30]	training's binary_logloss: 0.113861	valid_1's binary_logloss: 0.107719
# [31]	training's binary_logloss: 0.111423	valid_1's binary_logloss: 0.105165
# [32]	training's binary_logloss: 0.109234	valid_1's binary_logloss: 0.102859
# [33]	training's binary_logloss: 0.10726	valid_1's binary_logloss: 0.10078
# [34]	training's binary_logloss: 0.105491	valid_1's binary_logloss: 0.0989048
# [35]	training's binary_logloss: 0.103894	valid_1's binary_logloss: 0.097221
# [36]	training's binary_logloss: 0.102473	valid_1's binary_logloss: 0.0957062
# [37]	training's binary_logloss: 0.1012	valid_1's binary_logloss: 0.0943357
# [38]	training's binary_logloss: 0.100018	valid_1's binary_logloss: 0.0930778
# [39]	training's binary_logloss: 0.0989985	valid_1's binary_logloss: 0.0919833
# [40]	training's binary_logloss: 0.0980513	valid_1's binary_logloss: 0.0909723
# [41]	training's binary_logloss: 0.0972316	valid_1's binary_logloss: 0.0900732
# [42]	training's binary_logloss: 0.0964702	valid_1's binary_logloss: 0.0892409
# [43]	training's binary_logloss: 0.0958157	valid_1's binary_logloss: 0.0885148
# [44]	training's binary_logloss: 0.0951859	valid_1's binary_logloss: 0.0878385
# [45]	training's binary_logloss: 0.0946534	valid_1's binary_logloss: 0.0872619
# [46]	training's binary_logloss: 0.0941463	valid_1's binary_logloss: 0.0867132
# [47]	training's binary_logloss: 0.0936978	valid_1's binary_logloss: 0.0862136
# [48]	training's binary_logloss: 0.0933122	valid_1's binary_logloss: 0.0857954
# [49]	training's binary_logloss: 0.0929523	valid_1's binary_logloss: 0.0853941
# [50]	training's binary_logloss: 0.0926487	valid_1's binary_logloss: 0.0850536
# [51]	training's binary_logloss: 0.092351	valid_1's binary_logloss: 0.0847165
# [52]	training's binary_logloss: 0.0920999	valid_1's binary_logloss: 0.0844341
# [53]	training's binary_logloss: 0.0918686	valid_1's binary_logloss: 0.0841756
# [54]	training's binary_logloss: 0.0916383	valid_1's binary_logloss: 0.0839237
# [55]	training's binary_logloss: 0.0914539	valid_1's binary_logloss: 0.0837182
# [56]	training's binary_logloss: 0.0912882	valid_1's binary_logloss: 0.0835268
# [57]	training's binary_logloss: 0.0911131	valid_1's binary_logloss: 0.0833241
# [58]	training's binary_logloss: 0.0909648	valid_1's binary_logloss: 0.0831542
# [59]	training's binary_logloss: 0.0908397	valid_1's binary_logloss: 0.0829941
# [60]	training's binary_logloss: 0.0907222	valid_1's binary_logloss: 0.0828709
# [61]	training's binary_logloss: 0.0906103	valid_1's binary_logloss: 0.0827465
# [62]	training's binary_logloss: 0.0904854	valid_1's binary_logloss: 0.0826135
# [63]	training's binary_logloss: 0.0903945	valid_1's binary_logloss: 0.0825215
# [64]	training's binary_logloss: 0.0903029	valid_1's binary_logloss: 0.0824173
# [65]	training's binary_logloss: 0.0901921	valid_1's binary_logloss: 0.0823009
# [66]	training's binary_logloss: 0.090105	valid_1's binary_logloss: 0.082202
# [67]	training's binary_logloss: 0.0900171	valid_1's binary_logloss: 0.0821162
# [68]	training's binary_logloss: 0.0899455	valid_1's binary_logloss: 0.0820457
# [69]	training's binary_logloss: 0.0898826	valid_1's binary_logloss: 0.0819856
# [70]	training's binary_logloss: 0.0898042	valid_1's binary_logloss: 0.0819075
# [71]	training's binary_logloss: 0.0897352	valid_1's binary_logloss: 0.0818557
# [72]	training's binary_logloss: 0.0896812	valid_1's binary_logloss: 0.0817985
# [73]	training's binary_logloss: 0.0896234	valid_1's binary_logloss: 0.0817359
# [74]	training's binary_logloss: 0.0895743	valid_1's binary_logloss: 0.0816944
# [75]	training's binary_logloss: 0.0895084	valid_1's binary_logloss: 0.0816206
# [76]	training's binary_logloss: 0.0894612	valid_1's binary_logloss: 0.0815784
# [77]	training's binary_logloss: 0.0894093	valid_1's binary_logloss: 0.0815325
# [78]	training's binary_logloss: 0.0893486	valid_1's binary_logloss: 0.0814814
# [79]	training's binary_logloss: 0.0892873	valid_1's binary_logloss: 0.0814202
# [80]	training's binary_logloss: 0.089235	valid_1's binary_logloss: 0.0813745
# [81]	training's binary_logloss: 0.0891929	valid_1's binary_logloss: 0.0813449
# [82]	training's binary_logloss: 0.0891328	valid_1's binary_logloss: 0.0812956
# [83]	training's binary_logloss: 0.0890911	valid_1's binary_logloss: 0.0812596
# [84]	training's binary_logloss: 0.0890529	valid_1's binary_logloss: 0.0812442
# [85]	training's binary_logloss: 0.08901	valid_1's binary_logloss: 0.0812053
# [86]	training's binary_logloss: 0.0889757	valid_1's binary_logloss: 0.0811707
# [87]	training's binary_logloss: 0.0889315	valid_1's binary_logloss: 0.0811323
# [88]	training's binary_logloss: 0.0888847	valid_1's binary_logloss: 0.0810954
# [89]	training's binary_logloss: 0.0888511	valid_1's binary_logloss: 0.0810702
# [90]	training's binary_logloss: 0.088822	valid_1's binary_logloss: 0.0810427
# [91]	training's binary_logloss: 0.0887867	valid_1's binary_logloss: 0.0810033
# [92]	training's binary_logloss: 0.0887561	valid_1's binary_logloss: 0.08099
# [93]	training's binary_logloss: 0.0887202	valid_1's binary_logloss: 0.080961
# [94]	training's binary_logloss: 0.0886897	valid_1's binary_logloss: 0.0809314
# [95]	training's binary_logloss: 0.0886622	valid_1's binary_logloss: 0.0809174
# [96]	training's binary_logloss: 0.0886276	valid_1's binary_logloss: 0.0808916
# [97]	training's binary_logloss: 0.0886015	valid_1's binary_logloss: 0.0808758
# [98]	training's binary_logloss: 0.0885691	valid_1's binary_logloss: 0.0808569
# [99]	training's binary_logloss: 0.0885466	valid_1's binary_logloss: 0.0808379
# [100]	training's binary_logloss: 0.0885129	valid_1's binary_logloss: 0.0808097
# [101]	training's binary_logloss: 0.088482	valid_1's binary_logloss: 0.0807899
# [102]	training's binary_logloss: 0.0884573	valid_1's binary_logloss: 0.080778
# [103]	training's binary_logloss: 0.0884341	valid_1's binary_logloss: 0.08076
# [104]	training's binary_logloss: 0.0884107	valid_1's binary_logloss: 0.080741
# [105]	training's binary_logloss: 0.0883804	valid_1's binary_logloss: 0.0807211
# [106]	training's binary_logloss: 0.0883523	valid_1's binary_logloss: 0.0807018
# [107]	training's binary_logloss: 0.0883331	valid_1's binary_logloss: 0.0806825
# [108]	training's binary_logloss: 0.0883088	valid_1's binary_logloss: 0.0806746
# [109]	training's binary_logloss: 0.0882882	valid_1's binary_logloss: 0.0806651
# [110]	training's binary_logloss: 0.0882634	valid_1's binary_logloss: 0.0806401
# [111]	training's binary_logloss: 0.0882385	valid_1's binary_logloss: 0.0806256
# [112]	training's binary_logloss: 0.08822	valid_1's binary_logloss: 0.0806123
# [113]	training's binary_logloss: 0.0882009	valid_1's binary_logloss: 0.0806026
# [114]	training's binary_logloss: 0.0881747	valid_1's binary_logloss: 0.080582
# [115]	training's binary_logloss: 0.0881565	valid_1's binary_logloss: 0.0805698
# [116]	training's binary_logloss: 0.0881305	valid_1's binary_logloss: 0.0805513
# [117]	training's binary_logloss: 0.0881132	valid_1's binary_logloss: 0.0805424
# [118]	training's binary_logloss: 0.0880941	valid_1's binary_logloss: 0.0805337
# [119]	training's binary_logloss: 0.0880703	valid_1's binary_logloss: 0.0805129
# [120]	training's binary_logloss: 0.0880473	valid_1's binary_logloss: 0.0804931
# [121]	training's binary_logloss: 0.0880239	valid_1's binary_logloss: 0.0804786
# [122]	training's binary_logloss: 0.0879986	valid_1's binary_logloss: 0.0804742
# [123]	training's binary_logloss: 0.087979	valid_1's binary_logloss: 0.080457
# [124]	training's binary_logloss: 0.0879642	valid_1's binary_logloss: 0.0804507
# [125]	training's binary_logloss: 0.0879455	valid_1's binary_logloss: 0.0804345
# [126]	training's binary_logloss: 0.087931	valid_1's binary_logloss: 0.0804234
# [127]	training's binary_logloss: 0.0879163	valid_1's binary_logloss: 0.0804181
# [128]	training's binary_logloss: 0.0879013	valid_1's binary_logloss: 0.0804061
# [129]	training's binary_logloss: 0.0878885	valid_1's binary_logloss: 0.0804042
# [130]	training's binary_logloss: 0.0878669	valid_1's binary_logloss: 0.0803993
# [131]	training's binary_logloss: 0.0878515	valid_1's binary_logloss: 0.0803816
# [132]	training's binary_logloss: 0.087831	valid_1's binary_logloss: 0.0803683
# [133]	training's binary_logloss: 0.0878169	valid_1's binary_logloss: 0.0803551
# [134]	training's binary_logloss: 0.0878045	valid_1's binary_logloss: 0.0803469
# [135]	training's binary_logloss: 0.0877865	valid_1's binary_logloss: 0.0803367
# [136]	training's binary_logloss: 0.0877742	valid_1's binary_logloss: 0.0803343
# [137]	training's binary_logloss: 0.0877627	valid_1's binary_logloss: 0.0803292
# [138]	training's binary_logloss: 0.0877462	valid_1's binary_logloss: 0.0803115
# [139]	training's binary_logloss: 0.0877277	valid_1's binary_logloss: 0.0803042
# [140]	training's binary_logloss: 0.0877128	valid_1's binary_logloss: 0.0802919
# [141]	training's binary_logloss: 0.0876989	valid_1's binary_logloss: 0.0802889
# [142]	training's binary_logloss: 0.0876832	valid_1's binary_logloss: 0.0802857
# [143]	training's binary_logloss: 0.0876671	valid_1's binary_logloss: 0.0802737
# [144]	training's binary_logloss: 0.0876493	valid_1's binary_logloss: 0.0802606
# [145]	training's binary_logloss: 0.0876394	valid_1's binary_logloss: 0.0802554
# [146]	training's binary_logloss: 0.0876295	valid_1's binary_logloss: 0.0802455
# [147]	training's binary_logloss: 0.0876181	valid_1's binary_logloss: 0.0802375
# [148]	training's binary_logloss: 0.0876044	valid_1's binary_logloss: 0.0802307
# [149]	training's binary_logloss: 0.0875916	valid_1's binary_logloss: 0.0802306
# [150]	training's binary_logloss: 0.0875778	valid_1's binary_logloss: 0.0802271
# [151]	training's binary_logloss: 0.0875602	valid_1's binary_logloss: 0.0802144
# [152]	training's binary_logloss: 0.0875464	valid_1's binary_logloss: 0.0802113
# [153]	training's binary_logloss: 0.0875357	valid_1's binary_logloss: 0.0802079
# [154]	training's binary_logloss: 0.0875253	valid_1's binary_logloss: 0.0802045
# [155]	training's binary_logloss: 0.0875132	valid_1's binary_logloss: 0.0801995
# [156]	training's binary_logloss: 0.0875032	valid_1's binary_logloss: 0.0801981
# [157]	training's binary_logloss: 0.0874903	valid_1's binary_logloss: 0.080187
# [158]	training's binary_logloss: 0.0874758	valid_1's binary_logloss: 0.0801726
# [159]	training's binary_logloss: 0.0874642	valid_1's binary_logloss: 0.0801703
# [160]	training's binary_logloss: 0.0874533	valid_1's binary_logloss: 0.0801604
# [161]	training's binary_logloss: 0.0874385	valid_1's binary_logloss: 0.08016
# [162]	training's binary_logloss: 0.0874266	valid_1's binary_logloss: 0.0801481
# [163]	training's binary_logloss: 0.0874163	valid_1's binary_logloss: 0.0801455
# [164]	training's binary_logloss: 0.0874065	valid_1's binary_logloss: 0.0801445
# [165]	training's binary_logloss: 0.087387	valid_1's binary_logloss: 0.0801316
# [166]	training's binary_logloss: 0.0873764	valid_1's binary_logloss: 0.0801234
# [167]	training's binary_logloss: 0.0873651	valid_1's binary_logloss: 0.0801149
# [168]	training's binary_logloss: 0.0873518	valid_1's binary_logloss: 0.0801059
# [169]	training's binary_logloss: 0.0873422	valid_1's binary_logloss: 0.0800976
# [170]	training's binary_logloss: 0.0873288	valid_1's binary_logloss: 0.0800905
# [171]	training's binary_logloss: 0.0873208	valid_1's binary_logloss: 0.0800891
# [172]	training's binary_logloss: 0.0873121	valid_1's binary_logloss: 0.0800864
# [173]	training's binary_logloss: 0.0872991	valid_1's binary_logloss: 0.0800819
# [174]	training's binary_logloss: 0.0872897	valid_1's binary_logloss: 0.0800736
# [175]	training's binary_logloss: 0.0872798	valid_1's binary_logloss: 0.0800712
# [176]	training's binary_logloss: 0.087272	valid_1's binary_logloss: 0.0800633
# [177]	training's binary_logloss: 0.087265	valid_1's binary_logloss: 0.0800605
# [178]	training's binary_logloss: 0.0872517	valid_1's binary_logloss: 0.080051
# [179]	training's binary_logloss: 0.0872443	valid_1's binary_logloss: 0.0800457
# [180]	training's binary_logloss: 0.0872292	valid_1's binary_logloss: 0.0800407
# [181]	training's binary_logloss: 0.0872096	valid_1's binary_logloss: 0.0800363
# [182]	training's binary_logloss: 0.0872006	valid_1's binary_logloss: 0.0800349
# [183]	training's binary_logloss: 0.0871929	valid_1's binary_logloss: 0.0800332
# [184]	training's binary_logloss: 0.0871806	valid_1's binary_logloss: 0.0800296
# [185]	training's binary_logloss: 0.0871735	valid_1's binary_logloss: 0.0800297
# [186]	training's binary_logloss: 0.0871672	valid_1's binary_logloss: 0.0800258
# [187]	training's binary_logloss: 0.0871532	valid_1's binary_logloss: 0.0800187
# [188]	training's binary_logloss: 0.0871449	valid_1's binary_logloss: 0.0800178
# [189]	training's binary_logloss: 0.0871372	valid_1's binary_logloss: 0.0800156
# [190]	training's binary_logloss: 0.0871261	valid_1's binary_logloss: 0.0800123
# [191]	training's binary_logloss: 0.0871168	valid_1's binary_logloss: 0.080006
# [192]	training's binary_logloss: 0.0871104	valid_1's binary_logloss: 0.0800039
# [193]	training's binary_logloss: 0.0870996	valid_1's binary_logloss: 0.0800037
# [194]	training's binary_logloss: 0.0870896	valid_1's binary_logloss: 0.0799893
# [195]	training's binary_logloss: 0.0870825	valid_1's binary_logloss: 0.0799858
# [196]	training's binary_logloss: 0.0870747	valid_1's binary_logloss: 0.0799782
# [197]	training's binary_logloss: 0.0870657	valid_1's binary_logloss: 0.0799801
# [198]	training's binary_logloss: 0.087055	valid_1's binary_logloss: 0.0799774
# [199]	training's binary_logloss: 0.0870491	valid_1's binary_logloss: 0.079973
# [200]	training's binary_logloss: 0.0870428	valid_1's binary_logloss: 0.079973
# [201]	training's binary_logloss: 0.0870343	valid_1's binary_logloss: 0.0799745
# [202]	training's binary_logloss: 0.087029	valid_1's binary_logloss: 0.0799713
# [203]	training's binary_logloss: 0.087021	valid_1's binary_logloss: 0.0799636
# [204]	training's binary_logloss: 0.0870138	valid_1's binary_logloss: 0.0799566
# [205]	training's binary_logloss: 0.0870032	valid_1's binary_logloss: 0.0799568
# [206]	training's binary_logloss: 0.0869977	valid_1's binary_logloss: 0.0799584
# [207]	training's binary_logloss: 0.0869903	valid_1's binary_logloss: 0.0799581
# [208]	training's binary_logloss: 0.0869728	valid_1's binary_logloss: 0.0799506
# [209]	training's binary_logloss: 0.0869647	valid_1's binary_logloss: 0.0799482
# [210]	training's binary_logloss: 0.0869567	valid_1's binary_logloss: 0.0799459
# [211]	training's binary_logloss: 0.0869409	valid_1's binary_logloss: 0.0799451
# [212]	training's binary_logloss: 0.0869335	valid_1's binary_logloss: 0.0799465
# [213]	training's binary_logloss: 0.0869269	valid_1's binary_logloss: 0.0799445
# [214]	training's binary_logloss: 0.0869214	valid_1's binary_logloss: 0.0799457
# [215]	training's binary_logloss: 0.0869123	valid_1's binary_logloss: 0.0799425
# [216]	training's binary_logloss: 0.0869004	valid_1's binary_logloss: 0.0799323
# [217]	training's binary_logloss: 0.0868924	valid_1's binary_logloss: 0.0799253
# [218]	training's binary_logloss: 0.0868852	valid_1's binary_logloss: 0.0799202
# [219]	training's binary_logloss: 0.0868788	valid_1's binary_logloss: 0.0799214
# [220]	training's binary_logloss: 0.086873	valid_1's binary_logloss: 0.0799141
# [221]	training's binary_logloss: 0.0868642	valid_1's binary_logloss: 0.0799128
# [222]	training's binary_logloss: 0.0868548	valid_1's binary_logloss: 0.0799135
# [223]	training's binary_logloss: 0.0868499	valid_1's binary_logloss: 0.0799118
# [224]	training's binary_logloss: 0.0868427	valid_1's binary_logloss: 0.0799099
# [225]	training's binary_logloss: 0.0868316	valid_1's binary_logloss: 0.0799141
# [226]	training's binary_logloss: 0.0868216	valid_1's binary_logloss: 0.0799096
# [227]	training's binary_logloss: 0.0868131	valid_1's binary_logloss: 0.0799111
# [228]	training's binary_logloss: 0.0868049	valid_1's binary_logloss: 0.0799086
# [229]	training's binary_logloss: 0.0867956	valid_1's binary_logloss: 0.079907
# [230]	training's binary_logloss: 0.0867899	valid_1's binary_logloss: 0.0799073
# [231]	training's binary_logloss: 0.086779	valid_1's binary_logloss: 0.0798992
# [232]	training's binary_logloss: 0.0867731	valid_1's binary_logloss: 0.079894
# [233]	training's binary_logloss: 0.0867685	valid_1's binary_logloss: 0.0798958
# [234]	training's binary_logloss: 0.0867553	valid_1's binary_logloss: 0.0798872
# [235]	training's binary_logloss: 0.0867471	valid_1's binary_logloss: 0.0798848
# [236]	training's binary_logloss: 0.0867408	valid_1's binary_logloss: 0.0798862
# [237]	training's binary_logloss: 0.0867317	valid_1's binary_logloss: 0.0798811
# [238]	training's binary_logloss: 0.0867227	valid_1's binary_logloss: 0.0798748
# [239]	training's binary_logloss: 0.0867159	valid_1's binary_logloss: 0.0798725
# [240]	training's binary_logloss: 0.0867109	valid_1's binary_logloss: 0.0798693
# [241]	training's binary_logloss: 0.086702	valid_1's binary_logloss: 0.0798646
# [242]	training's binary_logloss: 0.0866966	valid_1's binary_logloss: 0.079862
# [243]	training's binary_logloss: 0.0866882	valid_1's binary_logloss: 0.0798622
# [244]	training's binary_logloss: 0.0866801	valid_1's binary_logloss: 0.0798533
# [245]	training's binary_logloss: 0.0866737	valid_1's binary_logloss: 0.0798482
# [246]	training's binary_logloss: 0.086664	valid_1's binary_logloss: 0.0798467
# [247]	training's binary_logloss: 0.0866578	valid_1's binary_logloss: 0.0798486
# [248]	training's binary_logloss: 0.0866539	valid_1's binary_logloss: 0.0798475
# [249]	training's binary_logloss: 0.08665	valid_1's binary_logloss: 0.0798467
# [250]	training's binary_logloss: 0.086645	valid_1's binary_logloss: 0.0798464
# [251]	training's binary_logloss: 0.0866367	valid_1's binary_logloss: 0.079847
# [252]	training's binary_logloss: 0.0866264	valid_1's binary_logloss: 0.0798432
# [253]	training's binary_logloss: 0.086621	valid_1's binary_logloss: 0.0798401
# [254]	training's binary_logloss: 0.0866163	valid_1's binary_logloss: 0.0798383
# [255]	training's binary_logloss: 0.086608	valid_1's binary_logloss: 0.0798342
# [256]	training's binary_logloss: 0.0865994	valid_1's binary_logloss: 0.0798327
# [257]	training's binary_logloss: 0.0865931	valid_1's binary_logloss: 0.0798311
# [258]	training's binary_logloss: 0.0865884	valid_1's binary_logloss: 0.0798305
# [259]	training's binary_logloss: 0.0865826	valid_1's binary_logloss: 0.0798329
# [260]	training's binary_logloss: 0.0865791	valid_1's binary_logloss: 0.0798307
# [261]	training's binary_logloss: 0.0865749	valid_1's binary_logloss: 0.0798301
# [262]	training's binary_logloss: 0.086569	valid_1's binary_logloss: 0.0798261
# [263]	training's binary_logloss: 0.086562	valid_1's binary_logloss: 0.0798271
# [264]	training's binary_logloss: 0.0865544	valid_1's binary_logloss: 0.0798254
# [265]	training's binary_logloss: 0.0865481	valid_1's binary_logloss: 0.0798263
# [266]	training's binary_logloss: 0.0865415	valid_1's binary_logloss: 0.079826
# [267]	training's binary_logloss: 0.0865306	valid_1's binary_logloss: 0.0798328
# [268]	training's binary_logloss: 0.086526	valid_1's binary_logloss: 0.0798311
# [269]	training's binary_logloss: 0.0865211	valid_1's binary_logloss: 0.0798321
# [270]	training's binary_logloss: 0.0865169	valid_1's binary_logloss: 0.0798311
# [271]	training's binary_logloss: 0.0865126	valid_1's binary_logloss: 0.0798314
# [272]	training's binary_logloss: 0.0865086	valid_1's binary_logloss: 0.0798328
# [273]	training's binary_logloss: 0.0865034	valid_1's binary_logloss: 0.0798328
# [274]	training's binary_logloss: 0.0864997	valid_1's binary_logloss: 0.0798332
# [275]	training's binary_logloss: 0.0864966	valid_1's binary_logloss: 0.0798317
# [276]	training's binary_logloss: 0.0864889	valid_1's binary_logloss: 0.0798298
# [277]	training's binary_logloss: 0.0864821	valid_1's binary_logloss: 0.0798282
# [278]	training's binary_logloss: 0.0864731	valid_1's binary_logloss: 0.0798266
# [279]	training's binary_logloss: 0.0864673	valid_1's binary_logloss: 0.0798287
# [280]	training's binary_logloss: 0.0864623	valid_1's binary_logloss: 0.0798327
# [281]	training's binary_logloss: 0.0864555	valid_1's binary_logloss: 0.0798249
# [282]	training's binary_logloss: 0.0864533	valid_1's binary_logloss: 0.0798247
# [283]	training's binary_logloss: 0.0864465	valid_1's binary_logloss: 0.0798207
# [284]	training's binary_logloss: 0.0864408	valid_1's binary_logloss: 0.0798164
# [285]	training's binary_logloss: 0.0864313	valid_1's binary_logloss: 0.0798195
# [286]	training's binary_logloss: 0.0864236	valid_1's binary_logloss: 0.0798148
# [287]	training's binary_logloss: 0.0864177	valid_1's binary_logloss: 0.0798147
# [288]	training's binary_logloss: 0.0864095	valid_1's binary_logloss: 0.0798134
# [289]	training's binary_logloss: 0.0864008	valid_1's binary_logloss: 0.0798126
# [290]	training's binary_logloss: 0.0863967	valid_1's binary_logloss: 0.0798109
# [291]	training's binary_logloss: 0.0863914	valid_1's binary_logloss: 0.0798118
# [292]	training's binary_logloss: 0.0863829	valid_1's binary_logloss: 0.0798086
# [293]	training's binary_logloss: 0.0863752	valid_1's binary_logloss: 0.079801
# [294]	training's binary_logloss: 0.0863701	valid_1's binary_logloss: 0.0798037
# [295]	training's binary_logloss: 0.0863632	valid_1's binary_logloss: 0.079799
# [296]	training's binary_logloss: 0.0863597	valid_1's binary_logloss: 0.0797968
# [297]	training's binary_logloss: 0.0863533	valid_1's binary_logloss: 0.0798009
# [298]	training's binary_logloss: 0.0863474	valid_1's binary_logloss: 0.0798025
# [299]	training's binary_logloss: 0.0863425	valid_1's binary_logloss: 0.079804
# [300]	training's binary_logloss: 0.0863373	valid_1's binary_logloss: 0.0798049
# [301]	training's binary_logloss: 0.0863341	valid_1's binary_logloss: 0.0798079
# [302]	training's binary_logloss: 0.0863296	valid_1's binary_logloss: 0.0798092
# [303]	training's binary_logloss: 0.0863232	valid_1's binary_logloss: 0.0798094
# [304]	training's binary_logloss: 0.0863196	valid_1's binary_logloss: 0.0798061
# [305]	training's binary_logloss: 0.086314	valid_1's binary_logloss: 0.0798097
# [306]	training's binary_logloss: 0.0863103	valid_1's binary_logloss: 0.0798095
# [307]	training's binary_logloss: 0.0863042	valid_1's binary_logloss: 0.0798082
# [308]	training's binary_logloss: 0.0863	valid_1's binary_logloss: 0.0798132
# [309]	training's binary_logloss: 0.0862964	valid_1's binary_logloss: 0.0798101
# [310]	training's binary_logloss: 0.0862937	valid_1's binary_logloss: 0.0798106
# [311]	training's binary_logloss: 0.0862868	valid_1's binary_logloss: 0.0798057
# [312]	training's binary_logloss: 0.0862763	valid_1's binary_logloss: 0.0798021
# [313]	training's binary_logloss: 0.0862673	valid_1's binary_logloss: 0.0798015
# [314]	training's binary_logloss: 0.0862629	valid_1's binary_logloss: 0.0798031
# [315]	training's binary_logloss: 0.0862584	valid_1's binary_logloss: 0.0798045
# [316]	training's binary_logloss: 0.0862542	valid_1's binary_logloss: 0.079806
# [317]	training's binary_logloss: 0.0862488	valid_1's binary_logloss: 0.0798025
# [318]	training's binary_logloss: 0.0862407	valid_1's binary_logloss: 0.079803
# [319]	training's binary_logloss: 0.0862367	valid_1's binary_logloss: 0.0798018
# [320]	training's binary_logloss: 0.0862315	valid_1's binary_logloss: 0.0798023
# [321]	training's binary_logloss: 0.0862229	valid_1's binary_logloss: 0.0798026
# [322]	training's binary_logloss: 0.0862163	valid_1's binary_logloss: 0.0797973
# [323]	training's binary_logloss: 0.0862067	valid_1's binary_logloss: 0.0797919
# [324]	training's binary_logloss: 0.0862017	valid_1's binary_logloss: 0.0797907
# [325]	training's binary_logloss: 0.0861942	valid_1's binary_logloss: 0.0797847
# [326]	training's binary_logloss: 0.0861879	valid_1's binary_logloss: 0.0797846
# [327]	training's binary_logloss: 0.0861849	valid_1's binary_logloss: 0.0797818
# [328]	training's binary_logloss: 0.086178	valid_1's binary_logloss: 0.0797754
# [329]	training's binary_logloss: 0.0861729	valid_1's binary_logloss: 0.0797741
# [330]	training's binary_logloss: 0.0861645	valid_1's binary_logloss: 0.0797699
# [331]	training's binary_logloss: 0.0861587	valid_1's binary_logloss: 0.0797724
# [332]	training's binary_logloss: 0.0861548	valid_1's binary_logloss: 0.0797714
# [333]	training's binary_logloss: 0.0861483	valid_1's binary_logloss: 0.0797703
# [334]	training's binary_logloss: 0.0861412	valid_1's binary_logloss: 0.0797731
# [335]	training's binary_logloss: 0.0861312	valid_1's binary_logloss: 0.0797646
# [336]	training's binary_logloss: 0.0861286	valid_1's binary_logloss: 0.0797642
# [337]	training's binary_logloss: 0.0861249	valid_1's binary_logloss: 0.0797657
# [338]	training's binary_logloss: 0.0861158	valid_1's binary_logloss: 0.0797619
# [339]	training's binary_logloss: 0.0861106	valid_1's binary_logloss: 0.0797574
# [340]	training's binary_logloss: 0.0861048	valid_1's binary_logloss: 0.0797544
# [341]	training's binary_logloss: 0.0861004	valid_1's binary_logloss: 0.079749
# [342]	training's binary_logloss: 0.0860929	valid_1's binary_logloss: 0.0797463
# [343]	training's binary_logloss: 0.0860846	valid_1's binary_logloss: 0.0797392
# [344]	training's binary_logloss: 0.0860821	valid_1's binary_logloss: 0.0797399
# [345]	training's binary_logloss: 0.0860766	valid_1's binary_logloss: 0.0797389
# [346]	training's binary_logloss: 0.0860723	valid_1's binary_logloss: 0.0797358
# [347]	training's binary_logloss: 0.0860676	valid_1's binary_logloss: 0.0797341
# [348]	training's binary_logloss: 0.0860649	valid_1's binary_logloss: 0.0797346
# [349]	training's binary_logloss: 0.0860624	valid_1's binary_logloss: 0.0797373
# [350]	training's binary_logloss: 0.0860564	valid_1's binary_logloss: 0.0797342
# [351]	training's binary_logloss: 0.0860506	valid_1's binary_logloss: 0.0797352
# [352]	training's binary_logloss: 0.0860474	valid_1's binary_logloss: 0.079734
# [353]	training's binary_logloss: 0.0860412	valid_1's binary_logloss: 0.0797287
# [354]	training's binary_logloss: 0.0860374	valid_1's binary_logloss: 0.0797314
# [355]	training's binary_logloss: 0.0860341	valid_1's binary_logloss: 0.0797323
# [356]	training's binary_logloss: 0.0860296	valid_1's binary_logloss: 0.0797342
# [357]	training's binary_logloss: 0.0860245	valid_1's binary_logloss: 0.079736
# [358]	training's binary_logloss: 0.0860197	valid_1's binary_logloss: 0.0797354
# [359]	training's binary_logloss: 0.0860114	valid_1's binary_logloss: 0.0797307
# [360]	training's binary_logloss: 0.0860075	valid_1's binary_logloss: 0.0797312
# [361]	training's binary_logloss: 0.086002	valid_1's binary_logloss: 0.0797325
# [362]	training's binary_logloss: 0.0859992	valid_1's binary_logloss: 0.0797333
# [363]	training's binary_logloss: 0.0859948	valid_1's binary_logloss: 0.0797344
# [364]	training's binary_logloss: 0.0859908	valid_1's binary_logloss: 0.079737
# [365]	training's binary_logloss: 0.0859875	valid_1's binary_logloss: 0.0797372
# [366]	training's binary_logloss: 0.0859825	valid_1's binary_logloss: 0.0797354
# [367]	training's binary_logloss: 0.085976	valid_1's binary_logloss: 0.0797328
# [368]	training's binary_logloss: 0.0859742	valid_1's binary_logloss: 0.0797312
# [369]	training's binary_logloss: 0.0859696	valid_1's binary_logloss: 0.0797277
# [370]	training's binary_logloss: 0.0859626	valid_1's binary_logloss: 0.0797268
# [371]	training's binary_logloss: 0.0859562	valid_1's binary_logloss: 0.0797247
# [372]	training's binary_logloss: 0.08595	valid_1's binary_logloss: 0.0797219
# [373]	training's binary_logloss: 0.0859456	valid_1's binary_logloss: 0.079719
# [374]	training's binary_logloss: 0.0859396	valid_1's binary_logloss: 0.0797178
# [375]	training's binary_logloss: 0.0859369	valid_1's binary_logloss: 0.0797184
# [376]	training's binary_logloss: 0.0859318	valid_1's binary_logloss: 0.0797182
# [377]	training's binary_logloss: 0.0859278	valid_1's binary_logloss: 0.0797173
# [378]	training's binary_logloss: 0.0859227	valid_1's binary_logloss: 0.0797153
# [379]	training's binary_logloss: 0.0859194	valid_1's binary_logloss: 0.0797159
# [380]	training's binary_logloss: 0.085914	valid_1's binary_logloss: 0.0797159
# [381]	training's binary_logloss: 0.0859095	valid_1's binary_logloss: 0.0797186
# [382]	training's binary_logloss: 0.0859073	valid_1's binary_logloss: 0.0797216
# [383]	training's binary_logloss: 0.0859053	valid_1's binary_logloss: 0.0797246
# [384]	training's binary_logloss: 0.0859023	valid_1's binary_logloss: 0.0797258
# [385]	training's binary_logloss: 0.0859	valid_1's binary_logloss: 0.0797239
# [386]	training's binary_logloss: 0.0858975	valid_1's binary_logloss: 0.079725
# [387]	training's binary_logloss: 0.0858927	valid_1's binary_logloss: 0.0797249
# [388]	training's binary_logloss: 0.0858885	valid_1's binary_logloss: 0.0797281
# [389]	training's binary_logloss: 0.085883	valid_1's binary_logloss: 0.079728
# [390]	training's binary_logloss: 0.0858775	valid_1's binary_logloss: 0.0797255
# [391]	training's binary_logloss: 0.0858714	valid_1's binary_logloss: 0.0797273
# [392]	training's binary_logloss: 0.0858678	valid_1's binary_logloss: 0.0797293
# [393]	training's binary_logloss: 0.0858653	valid_1's binary_logloss: 0.0797329
# [394]	training's binary_logloss: 0.0858603	valid_1's binary_logloss: 0.0797441
# [395]	training's binary_logloss: 0.0858569	valid_1's binary_logloss: 0.0797434
# [396]	training's binary_logloss: 0.0858529	valid_1's binary_logloss: 0.0797439
# [397]	training's binary_logloss: 0.0858505	valid_1's binary_logloss: 0.0797429
# [398]	training's binary_logloss: 0.0858477	valid_1's binary_logloss: 0.0797428
# [399]	training's binary_logloss: 0.0858414	valid_1's binary_logloss: 0.079739
# [400]	training's binary_logloss: 0.0858367	valid_1's binary_logloss: 0.0797359
# [401]	training's binary_logloss: 0.0858321	valid_1's binary_logloss: 0.0797334
# [402]	training's binary_logloss: 0.0858258	valid_1's binary_logloss: 0.0797339
# [403]	training's binary_logloss: 0.0858217	valid_1's binary_logloss: 0.0797354
# [404]	training's binary_logloss: 0.0858189	valid_1's binary_logloss: 0.0797355
# [405]	training's binary_logloss: 0.0858146	valid_1's binary_logloss: 0.0797391
# [406]	training's binary_logloss: 0.0858086	valid_1's binary_logloss: 0.0797405
# [407]	training's binary_logloss: 0.0858057	valid_1's binary_logloss: 0.0797383
# [408]	training's binary_logloss: 0.0858002	valid_1's binary_logloss: 0.0797388
# [409]	training's binary_logloss: 0.0857925	valid_1's binary_logloss: 0.079738
# [410]	training's binary_logloss: 0.0857888	valid_1's binary_logloss: 0.0797325
# [411]	training's binary_logloss: 0.0857864	valid_1's binary_logloss: 0.0797331
# [412]	training's binary_logloss: 0.0857841	valid_1's binary_logloss: 0.0797293
# [413]	training's binary_logloss: 0.0857815	valid_1's binary_logloss: 0.0797301
# [414]	training's binary_logloss: 0.0857778	valid_1's binary_logloss: 0.0797287
# [415]	training's binary_logloss: 0.0857751	valid_1's binary_logloss: 0.0797276
# [416]	training's binary_logloss: 0.0857684	valid_1's binary_logloss: 0.0797231
# [417]	training's binary_logloss: 0.0857676	valid_1's binary_logloss: 0.0797228
# [418]	training's binary_logloss: 0.0857613	valid_1's binary_logloss: 0.0797219
# [419]	training's binary_logloss: 0.0857559	valid_1's binary_logloss: 0.0797197
# [420]	training's binary_logloss: 0.0857498	valid_1's binary_logloss: 0.0797163
# [421]	training's binary_logloss: 0.0857474	valid_1's binary_logloss: 0.0797177
# [422]	training's binary_logloss: 0.0857466	valid_1's binary_logloss: 0.0797171
# [423]	training's binary_logloss: 0.0857435	valid_1's binary_logloss: 0.0797174
# [424]	training's binary_logloss: 0.0857387	valid_1's binary_logloss: 0.079719
# [425]	training's binary_logloss: 0.0857334	valid_1's binary_logloss: 0.0797199
# [426]	training's binary_logloss: 0.0857285	valid_1's binary_logloss: 0.0797216
# [427]	training's binary_logloss: 0.0857238	valid_1's binary_logloss: 0.0797162
# [428]	training's binary_logloss: 0.0857183	valid_1's binary_logloss: 0.0797154
# [429]	training's binary_logloss: 0.0857098	valid_1's binary_logloss: 0.0797172
# [430]	training's binary_logloss: 0.0857044	valid_1's binary_logloss: 0.0797184
# [431]	training's binary_logloss: 0.0857017	valid_1's binary_logloss: 0.0797178
# [432]	training's binary_logloss: 0.0856975	valid_1's binary_logloss: 0.0797174
# [433]	training's binary_logloss: 0.0856931	valid_1's binary_logloss: 0.0797162
# [434]	training's binary_logloss: 0.0856911	valid_1's binary_logloss: 0.0797144
# [435]	training's binary_logloss: 0.0856885	valid_1's binary_logloss: 0.0797156
# [436]	training's binary_logloss: 0.0856859	valid_1's binary_logloss: 0.0797181
# [437]	training's binary_logloss: 0.0856801	valid_1's binary_logloss: 0.0797225
# [438]	training's binary_logloss: 0.0856743	valid_1's binary_logloss: 0.0797234
# [439]	training's binary_logloss: 0.0856678	valid_1's binary_logloss: 0.0797132
# [440]	training's binary_logloss: 0.085662	valid_1's binary_logloss: 0.0797151
# [441]	training's binary_logloss: 0.0856568	valid_1's binary_logloss: 0.0797142
# [442]	training's binary_logloss: 0.0856521	valid_1's binary_logloss: 0.0797139
# [443]	training's binary_logloss: 0.0856469	valid_1's binary_logloss: 0.0797176
# [444]	training's binary_logloss: 0.08564	valid_1's binary_logloss: 0.0797172
# [445]	training's binary_logloss: 0.0856347	valid_1's binary_logloss: 0.0797149
# [446]	training's binary_logloss: 0.0856306	valid_1's binary_logloss: 0.0797123
# [447]	training's binary_logloss: 0.0856258	valid_1's binary_logloss: 0.0797148
# [448]	training's binary_logloss: 0.08562	valid_1's binary_logloss: 0.0797156
# [449]	training's binary_logloss: 0.0856154	valid_1's binary_logloss: 0.079716
# [450]	training's binary_logloss: 0.0856127	valid_1's binary_logloss: 0.0797181
# [451]	training's binary_logloss: 0.0856083	valid_1's binary_logloss: 0.0797163
# [452]	training's binary_logloss: 0.0856018	valid_1's binary_logloss: 0.0797161
# [453]	training's binary_logloss: 0.0855982	valid_1's binary_logloss: 0.0797173
# [454]	training's binary_logloss: 0.0855937	valid_1's binary_logloss: 0.0797175
# [455]	training's binary_logloss: 0.0855884	valid_1's binary_logloss: 0.0797174
# [456]	training's binary_logloss: 0.0855848	valid_1's binary_logloss: 0.0797226
# [457]	training's binary_logloss: 0.0855828	valid_1's binary_logloss: 0.0797207
# [458]	training's binary_logloss: 0.0855806	valid_1's binary_logloss: 0.0797215
# [459]	training's binary_logloss: 0.0855761	valid_1's binary_logloss: 0.079722
# [460]	training's binary_logloss: 0.0855744	valid_1's binary_logloss: 0.0797201
# [461]	training's binary_logloss: 0.08557	valid_1's binary_logloss: 0.0797207
# [462]	training's binary_logloss: 0.0855681	valid_1's binary_logloss: 0.0797204
# [463]	training's binary_logloss: 0.0855634	valid_1's binary_logloss: 0.0797213
# [464]	training's binary_logloss: 0.0855614	valid_1's binary_logloss: 0.0797214
# [465]	training's binary_logloss: 0.085558	valid_1's binary_logloss: 0.079723
# [466]	training's binary_logloss: 0.0855542	valid_1's binary_logloss: 0.0797286
# [467]	training's binary_logloss: 0.0855478	valid_1's binary_logloss: 0.0797292
# [468]	training's binary_logloss: 0.0855428	valid_1's binary_logloss: 0.0797282
# [469]	training's binary_logloss: 0.0855371	valid_1's binary_logloss: 0.0797278
# [470]	training's binary_logloss: 0.0855336	valid_1's binary_logloss: 0.0797248
# [471]	training's binary_logloss: 0.0855329	valid_1's binary_logloss: 0.0797243
# [472]	training's binary_logloss: 0.0855275	valid_1's binary_logloss: 0.0797198
# [473]	training's binary_logloss: 0.085526	valid_1's binary_logloss: 0.0797173
# [474]	training's binary_logloss: 0.0855214	valid_1's binary_logloss: 0.0797148
# [475]	training's binary_logloss: 0.0855184	valid_1's binary_logloss: 0.0797151
# [476]	training's binary_logloss: 0.085514	valid_1's binary_logloss: 0.0797136
# [477]	training's binary_logloss: 0.0855074	valid_1's binary_logloss: 0.0797152
# [478]	training's binary_logloss: 0.0855022	valid_1's binary_logloss: 0.0797145
# [479]	training's binary_logloss: 0.0854987	valid_1's binary_logloss: 0.0797173
# [480]	training's binary_logloss: 0.0854965	valid_1's binary_logloss: 0.0797181
# [481]	training's binary_logloss: 0.085493	valid_1's binary_logloss: 0.0797196
# [482]	training's binary_logloss: 0.0854877	valid_1's binary_logloss: 0.0797189
# [483]	training's binary_logloss: 0.0854859	valid_1's binary_logloss: 0.0797161
# [484]	training's binary_logloss: 0.085481	valid_1's binary_logloss: 0.0797179
# [485]	training's binary_logloss: 0.0854774	valid_1's binary_logloss: 0.0797195
# [486]	training's binary_logloss: 0.0854753	valid_1's binary_logloss: 0.0797207
# [487]	training's binary_logloss: 0.0854733	valid_1's binary_logloss: 0.079718
# [488]	training's binary_logloss: 0.0854698	valid_1's binary_logloss: 0.0797183
# [489]	training's binary_logloss: 0.0854656	valid_1's binary_logloss: 0.0797189
# [490]	training's binary_logloss: 0.0854612	valid_1's binary_logloss: 0.0797184
# [491]	training's binary_logloss: 0.0854557	valid_1's binary_logloss: 0.0797192
# [492]	training's binary_logloss: 0.0854503	valid_1's binary_logloss: 0.0797192
# [493]	training's binary_logloss: 0.0854478	valid_1's binary_logloss: 0.0797191
# [494]	training's binary_logloss: 0.0854402	valid_1's binary_logloss: 0.0797204
# [495]	training's binary_logloss: 0.0854361	valid_1's binary_logloss: 0.0797204
# [496]	training's binary_logloss: 0.0854319	valid_1's binary_logloss: 0.0797178
# [497]	training's binary_logloss: 0.0854276	valid_1's binary_logloss: 0.0797191
# [498]	training's binary_logloss: 0.0854253	valid_1's binary_logloss: 0.079722
# [499]	training's binary_logloss: 0.0854214	valid_1's binary_logloss: 0.0797204
# [500]	training's binary_logloss: 0.0854207	valid_1's binary_logloss: 0.0797199
# [501]	training's binary_logloss: 0.0854159	valid_1's binary_logloss: 0.0797133
# [502]	training's binary_logloss: 0.0854123	valid_1's binary_logloss: 0.0797141
# [503]	training's binary_logloss: 0.0854079	valid_1's binary_logloss: 0.0797127
# [504]	training's binary_logloss: 0.0854038	valid_1's binary_logloss: 0.0797153
# [505]	training's binary_logloss: 0.0853965	valid_1's binary_logloss: 0.0797133
# [506]	training's binary_logloss: 0.0853947	valid_1's binary_logloss: 0.0797148
# [507]	training's binary_logloss: 0.0853925	valid_1's binary_logloss: 0.0797148
# [508]	training's binary_logloss: 0.0853881	valid_1's binary_logloss: 0.0797164
# [509]	training's binary_logloss: 0.085386	valid_1's binary_logloss: 0.0797193
# [510]	training's binary_logloss: 0.0853827	valid_1's binary_logloss: 0.0797189
# [511]	training's binary_logloss: 0.0853783	valid_1's binary_logloss: 0.0797193
# [512]	training's binary_logloss: 0.0853713	valid_1's binary_logloss: 0.0797191
# [513]	training's binary_logloss: 0.0853646	valid_1's binary_logloss: 0.0797175
# [514]	training's binary_logloss: 0.0853586	valid_1's binary_logloss: 0.0797181
# [515]	training's binary_logloss: 0.0853544	valid_1's binary_logloss: 0.0797194
# [516]	training's binary_logloss: 0.0853538	valid_1's binary_logloss: 0.0797185
# [517]	training's binary_logloss: 0.0853505	valid_1's binary_logloss: 0.0797213
# [518]	training's binary_logloss: 0.0853488	valid_1's binary_logloss: 0.0797194
# [519]	training's binary_logloss: 0.0853447	valid_1's binary_logloss: 0.0797161
# [520]	training's binary_logloss: 0.0853408	valid_1's binary_logloss: 0.079714
# [521]	training's binary_logloss: 0.0853371	valid_1's binary_logloss: 0.0797168
# [522]	training's binary_logloss: 0.0853337	valid_1's binary_logloss: 0.0797174
# [523]	training's binary_logloss: 0.0853289	valid_1's binary_logloss: 0.0797172
# [524]	training's binary_logloss: 0.0853255	valid_1's binary_logloss: 0.0797204
# [525]	training's binary_logloss: 0.0853216	valid_1's binary_logloss: 0.0797233
# [526]	training's binary_logloss: 0.0853186	valid_1's binary_logloss: 0.079726
# [527]	training's binary_logloss: 0.0853133	valid_1's binary_logloss: 0.0797171
# [528]	training's binary_logloss: 0.0853115	valid_1's binary_logloss: 0.0797167
# [529]	training's binary_logloss: 0.0853056	valid_1's binary_logloss: 0.0797166
# [530]	training's binary_logloss: 0.0853039	valid_1's binary_logloss: 0.0797159
# [531]	training's binary_logloss: 0.085303	valid_1's binary_logloss: 0.0797176
# [532]	training's binary_logloss: 0.0852993	valid_1's binary_logloss: 0.0797166
# [533]	training's binary_logloss: 0.0852971	valid_1's binary_logloss: 0.0797219
# [534]	training's binary_logloss: 0.0852943	valid_1's binary_logloss: 0.0797236
# [535]	training's binary_logloss: 0.0852904	valid_1's binary_logloss: 0.0797205
# [536]	training's binary_logloss: 0.0852841	valid_1's binary_logloss: 0.0797197
# [537]	training's binary_logloss: 0.0852813	valid_1's binary_logloss: 0.0797247
# [538]	training's binary_logloss: 0.0852768	valid_1's binary_logloss: 0.0797254
# [539]	training's binary_logloss: 0.0852713	valid_1's binary_logloss: 0.0797243
# [540]	training's binary_logloss: 0.0852658	valid_1's binary_logloss: 0.0797262
# [541]	training's binary_logloss: 0.085264	valid_1's binary_logloss: 0.0797264
# [542]	training's binary_logloss: 0.0852589	valid_1's binary_logloss: 0.0797269
# [543]	training's binary_logloss: 0.0852552	valid_1's binary_logloss: 0.0797222
# [544]	training's binary_logloss: 0.0852513	valid_1's binary_logloss: 0.0797191
# [545]	training's binary_logloss: 0.0852496	valid_1's binary_logloss: 0.0797197
# [546]	training's binary_logloss: 0.0852457	valid_1's binary_logloss: 0.0797183
# [547]	training's binary_logloss: 0.0852418	valid_1's binary_logloss: 0.0797214
# [548]	training's binary_logloss: 0.0852391	valid_1's binary_logloss: 0.0797235
# [549]	training's binary_logloss: 0.0852361	valid_1's binary_logloss: 0.0797248
# [550]	training's binary_logloss: 0.0852318	valid_1's binary_logloss: 0.0797275
# [551]	training's binary_logloss: 0.0852286	valid_1's binary_logloss: 0.0797257
# [552]	training's binary_logloss: 0.0852241	valid_1's binary_logloss: 0.0797233
# [553]	training's binary_logloss: 0.0852205	valid_1's binary_logloss: 0.0797236
# [554]	training's binary_logloss: 0.0852189	valid_1's binary_logloss: 0.0797221
# [555]	training's binary_logloss: 0.0852166	valid_1's binary_logloss: 0.0797266
# [556]	training's binary_logloss: 0.0852144	valid_1's binary_logloss: 0.0797272
# [557]	training's binary_logloss: 0.085213	valid_1's binary_logloss: 0.0797281
# [558]	training's binary_logloss: 0.0852084	valid_1's binary_logloss: 0.0797272
# [559]	training's binary_logloss: 0.0852024	valid_1's binary_logloss: 0.0797272
# [560]	training's binary_logloss: 0.0851991	valid_1's binary_logloss: 0.0797267
# [561]	training's binary_logloss: 0.0851935	valid_1's binary_logloss: 0.0797274
# [562]	training's binary_logloss: 0.085189	valid_1's binary_logloss: 0.0797246
# [563]	training's binary_logloss: 0.0851849	valid_1's binary_logloss: 0.0797266
# [564]	training's binary_logloss: 0.0851792	valid_1's binary_logloss: 0.0797265
# [565]	training's binary_logloss: 0.085176	valid_1's binary_logloss: 0.0797274
# [566]	training's binary_logloss: 0.0851745	valid_1's binary_logloss: 0.0797282
# [567]	training's binary_logloss: 0.0851734	valid_1's binary_logloss: 0.0797272
# [568]	training's binary_logloss: 0.0851696	valid_1's binary_logloss: 0.0797292
# [569]	training's binary_logloss: 0.0851679	valid_1's binary_logloss: 0.0797282
# [570]	training's binary_logloss: 0.0851658	valid_1's binary_logloss: 0.0797296
# [571]	training's binary_logloss: 0.0851625	valid_1's binary_logloss: 0.0797305
# [572]	training's binary_logloss: 0.0851583	valid_1's binary_logloss: 0.0797317
# [573]	training's binary_logloss: 0.0851547	valid_1's binary_logloss: 0.0797314
# [574]	training's binary_logloss: 0.0851501	valid_1's binary_logloss: 0.0797236
# [575]	training's binary_logloss: 0.0851467	valid_1's binary_logloss: 0.0797185
# [576]	training's binary_logloss: 0.0851422	valid_1's binary_logloss: 0.0797215
# [577]	training's binary_logloss: 0.0851382	valid_1's binary_logloss: 0.0797218
# [578]	training's binary_logloss: 0.0851347	valid_1's binary_logloss: 0.0797213
# [579]	training's binary_logloss: 0.0851307	valid_1's binary_logloss: 0.0797217
# [580]	training's binary_logloss: 0.0851261	valid_1's binary_logloss: 0.0797233
# [581]	training's binary_logloss: 0.0851218	valid_1's binary_logloss: 0.0797264
# [582]	training's binary_logloss: 0.0851202	valid_1's binary_logloss: 0.0797269
# [583]	training's binary_logloss: 0.0851168	valid_1's binary_logloss: 0.0797262
# [584]	training's binary_logloss: 0.0851163	valid_1's binary_logloss: 0.0797264
# [585]	training's binary_logloss: 0.0851123	valid_1's binary_logloss: 0.0797283
# [586]	training's binary_logloss: 0.0851094	valid_1's binary_logloss: 0.0797262
# [587]	training's binary_logloss: 0.0851074	valid_1's binary_logloss: 0.0797274
# [588]	training's binary_logloss: 0.0851021	valid_1's binary_logloss: 0.07973
# [589]	training's binary_logloss: 0.085101	valid_1's binary_logloss: 0.0797323
# [590]	training's binary_logloss: 0.0850987	valid_1's binary_logloss: 0.0797317
# [591]	training's binary_logloss: 0.0850964	valid_1's binary_logloss: 0.0797313
# [592]	training's binary_logloss: 0.0850922	valid_1's binary_logloss: 0.0797255
# [593]	training's binary_logloss: 0.0850883	valid_1's binary_logloss: 0.0797281
# [594]	training's binary_logloss: 0.0850846	valid_1's binary_logloss: 0.079732
# [595]	training's binary_logloss: 0.085081	valid_1's binary_logloss: 0.0797295
# [596]	training's binary_logloss: 0.0850766	valid_1's binary_logloss: 0.0797292
# [597]	training's binary_logloss: 0.0850733	valid_1's binary_logloss: 0.0797293
# [598]	training's binary_logloss: 0.0850693	valid_1's binary_logloss: 0.0797292
# [599]	training's binary_logloss: 0.0850666	valid_1's binary_logloss: 0.079728
# [600]	training's binary_logloss: 0.0850652	valid_1's binary_logloss: 0.0797272
# [601]	training's binary_logloss: 0.0850612	valid_1's binary_logloss: 0.079732
# [602]	training's binary_logloss: 0.0850569	valid_1's binary_logloss: 0.07973
# [603]	training's binary_logloss: 0.085053	valid_1's binary_logloss: 0.0797334
# [604]	training's binary_logloss: 0.0850501	valid_1's binary_logloss: 0.0797319
# [605]	training's binary_logloss: 0.0850462	valid_1's binary_logloss: 0.0797248
# [606]	training's binary_logloss: 0.0850442	valid_1's binary_logloss: 0.0797252
# [607]	training's binary_logloss: 0.0850415	valid_1's binary_logloss: 0.0797251
# [608]	training's binary_logloss: 0.0850393	valid_1's binary_logloss: 0.0797253
# [609]	training's binary_logloss: 0.0850363	valid_1's binary_logloss: 0.0797265
# [610]	training's binary_logloss: 0.0850318	valid_1's binary_logloss: 0.0797238
# ...
# [697]	training's binary_logloss: 0.0847787	valid_1's binary_logloss: 0.0796796
# [698]	training's binary_logloss: 0.0847749	valid_1's binary_logloss: 0.0796815
# [699]	training's binary_logloss: 0.0847709	valid_1's binary_logloss: 0.07968
# [700]	training's binary_logloss: 0.0847678	valid_1's binary_logloss: 0.0796802
# [701]	training's binary_logloss: 0.0847646	valid_1's binary_logloss: 0.0796802
# [702]	training's binary_logloss: 0.0847615	valid_1's binary_logloss: 0.07968
# [703]	training's binary_logloss: 0.0847587	valid_1's binary_logloss: 0.0796809
# [704]	training's binary_logloss: 0.0847551	valid_1's binary_logloss: 0.0796809
# [705]	training's binary_logloss: 0.0847484	valid_1's binary_logloss: 0.0796818
# [706]	training's binary_logloss: 0.0847452	valid_1's binary_logloss: 0.0796825
# [707]	training's binary_logloss: 0.0847439	valid_1's binary_logloss: 0.0796815
# [708]	training's binary_logloss: 0.0847398	valid_1's binary_logloss: 0.0796826
# [709]	training's binary_logloss: 0.0847349	valid_1's binary_logloss: 0.0796859
# [710]	training's binary_logloss: 0.0847323	valid_1's binary_logloss: 0.0796872
# [711]	training's binary_logloss: 0.0847292	valid_1's binary_logloss: 0.0796868
# [712]	training's binary_logloss: 0.0847269	valid_1's binary_logloss: 0.079686
# [713]	training's binary_logloss: 0.084725	valid_1's binary_logloss: 0.0796879
# [714]	training's binary_logloss: 0.0847241	valid_1's binary_logloss: 0.0796881
# [715]	training's binary_logloss: 0.0847227	valid_1's binary_logloss: 0.0796878
# [716]	training's binary_logloss: 0.0847199	valid_1's binary_logloss: 0.0796908
# [717]	training's binary_logloss: 0.0847143	valid_1's binary_logloss: 0.079694
# [718]	training's binary_logloss: 0.0847115	valid_1's binary_logloss: 0.0796947
# [719]	training's binary_logloss: 0.0847112	valid_1's binary_logloss: 0.0796947
# [720]	training's binary_logloss: 0.0847071	valid_1's binary_logloss: 0.0796964
# [721]	training's binary_logloss: 0.0847029	valid_1's binary_logloss: 0.0796948
# [722]	training's binary_logloss: 0.0846999	valid_1's binary_logloss: 0.0796954
# [723]	training's binary_logloss: 0.084697	valid_1's binary_logloss: 0.0796935
# [724]	training's binary_logloss: 0.0846908	valid_1's binary_logloss: 0.0796973
# [725]	training's binary_logloss: 0.0846878	valid_1's binary_logloss: 0.0796993
# [726]	training's binary_logloss: 0.0846851	valid_1's binary_logloss: 0.0796983
# [727]	training's binary_logloss: 0.0846823	valid_1's binary_logloss: 0.0797002
# [728]	training's binary_logloss: 0.0846794	valid_1's binary_logloss: 0.0796981
# [729]	training's binary_logloss: 0.0846744	valid_1's binary_logloss: 0.0797041
# [730]	training's binary_logloss: 0.0846733	valid_1's binary_logloss: 0.0797036
# [731]	training's binary_logloss: 0.084672	valid_1's binary_logloss: 0.0797033
# [732]	training's binary_logloss: 0.0846689	valid_1's binary_logloss: 0.0797054
# [733]	training's binary_logloss: 0.0846632	valid_1's binary_logloss: 0.0797064
# [734]	training's binary_logloss: 0.0846599	valid_1's binary_logloss: 0.0797035
# [735]	training's binary_logloss: 0.0846578	valid_1's binary_logloss: 0.0797039
# [736]	training's binary_logloss: 0.0846548	valid_1's binary_logloss: 0.079706
# [737]	training's binary_logloss: 0.0846508	valid_1's binary_logloss: 0.0797088
# [738]	training's binary_logloss: 0.0846455	valid_1's binary_logloss: 0.0797089
# [739]	training's binary_logloss: 0.0846423	valid_1's binary_logloss: 0.0797084
# [740]	training's binary_logloss: 0.0846396	valid_1's binary_logloss: 0.0797108
# [741]	training's binary_logloss: 0.0846365	valid_1's binary_logloss: 0.079709
# [742]	training's binary_logloss: 0.0846322	valid_1's binary_logloss: 0.079711
# [743]	training's binary_logloss: 0.0846319	valid_1's binary_logloss: 0.0797108
# [744]	training's binary_logloss: 0.0846311	valid_1's binary_logloss: 0.0797121
# [745]	training's binary_logloss: 0.0846276	valid_1's binary_logloss: 0.0797088
# [746]	training's binary_logloss: 0.0846252	valid_1's binary_logloss: 0.0797092
# [747]	training's binary_logloss: 0.084623	valid_1's binary_logloss: 0.079709
# [748]	training's binary_logloss: 0.084619	valid_1's binary_logloss: 0.0797111
# [749]	training's binary_logloss: 0.0846137	valid_1's binary_logloss: 0.0797101
# [750]	training's binary_logloss: 0.0846103	valid_1's binary_logloss: 0.0797098
# [751]	training's binary_logloss: 0.0846059	valid_1's binary_logloss: 0.079712
# [752]	training's binary_logloss: 0.0846031	valid_1's binary_logloss: 0.0797116
# [753]	training's binary_logloss: 0.0846014	valid_1's binary_logloss: 0.0797152
# [754]	training's binary_logloss: 0.0845968	valid_1's binary_logloss: 0.0797161
# [755]	training's binary_logloss: 0.0845942	valid_1's binary_logloss: 0.0797156
# [756]	training's binary_logloss: 0.0845888	valid_1's binary_logloss: 0.0797139
# [757]	training's binary_logloss: 0.084587	valid_1's binary_logloss: 0.0797168
# [758]	training's binary_logloss: 0.0845839	valid_1's binary_logloss: 0.0797181
# [759]	training's binary_logloss: 0.0845812	valid_1's binary_logloss: 0.0797189
# [760]	training's binary_logloss: 0.084578	valid_1's binary_logloss: 0.0797202
# [761]	training's binary_logloss: 0.0845732	valid_1's binary_logloss: 0.0797213
# [762]	training's binary_logloss: 0.0845691	valid_1's binary_logloss: 0.0797255
# [763]	training's binary_logloss: 0.0845653	valid_1's binary_logloss: 0.0797272
# [764]	training's binary_logloss: 0.084561	valid_1's binary_logloss: 0.0797283
# [765]	training's binary_logloss: 0.0845555	valid_1's binary_logloss: 0.0797336
# [766]	training's binary_logloss: 0.0845551	valid_1's binary_logloss: 0.0797337
# [767]	training's binary_logloss: 0.084552	valid_1's binary_logloss: 0.0797362
# [768]	training's binary_logloss: 0.0845494	valid_1's binary_logloss: 0.0797357
# [769]	training's binary_logloss: 0.084545	valid_1's binary_logloss: 0.0797366
# [770]	training's binary_logloss: 0.0845414	valid_1's binary_logloss: 0.0797373
# [771]	training's binary_logloss: 0.084539	valid_1's binary_logloss: 0.0797373
# [772]	training's binary_logloss: 0.0845344	valid_1's binary_logloss: 0.0797342
# [773]	training's binary_logloss: 0.084532	valid_1's binary_logloss: 0.0797341
# [774]	training's binary_logloss: 0.0845274	valid_1's binary_logloss: 0.0797357
# [775]	training's binary_logloss: 0.0845246	valid_1's binary_logloss: 0.0797357
# [776]	training's binary_logloss: 0.0845197	valid_1's binary_logloss: 0.0797322
# [777]	training's binary_logloss: 0.0845166	valid_1's binary_logloss: 0.0797312
# [778]	training's binary_logloss: 0.0845142	valid_1's binary_logloss: 0.0797315
# [779]	training's binary_logloss: 0.0845104	valid_1's binary_logloss: 0.0797278
# [780]	training's binary_logloss: 0.0845082	valid_1's binary_logloss: 0.0797307
# [781]	training's binary_logloss: 0.0845072	valid_1's binary_logloss: 0.0797296
# [782]	training's binary_logloss: 0.084506	valid_1's binary_logloss: 0.0797272
# [783]	training's binary_logloss: 0.0845042	valid_1's binary_logloss: 0.0797294
# [784]	training's binary_logloss: 0.0845004	valid_1's binary_logloss: 0.0797274
# [785]	training's binary_logloss: 0.084497	valid_1's binary_logloss: 0.0797247
# [786]	training's binary_logloss: 0.0844935	valid_1's binary_logloss: 0.0797266
# [787]	training's binary_logloss: 0.0844903	valid_1's binary_logloss: 0.0797294
# [788]	training's binary_logloss: 0.0844858	valid_1's binary_logloss: 0.0797278
# [789]	training's binary_logloss: 0.0844815	valid_1's binary_logloss: 0.079731
# [790]	training's binary_logloss: 0.0844788	valid_1's binary_logloss: 0.0797323
# [791]	training's binary_logloss: 0.0844757	valid_1's binary_logloss: 0.0797344
# [792]	training's binary_logloss: 0.0844721	valid_1's binary_logloss: 0.0797357
# [793]	training's binary_logloss: 0.0844675	valid_1's binary_logloss: 0.0797365
# [794]	training's binary_logloss: 0.0844657	valid_1's binary_logloss: 0.0797372
# [795]	training's binary_logloss: 0.084464	valid_1's binary_logloss: 0.0797355
# [796]	training's binary_logloss: 0.0844622	valid_1's binary_logloss: 0.0797363
# [797]	training's binary_logloss: 0.084459	valid_1's binary_logloss: 0.0797361
# [798]	training's binary_logloss: 0.0844553	valid_1's binary_logloss: 0.0797365
# [799]	training's binary_logloss: 0.0844511	valid_1's binary_logloss: 0.0797351
# [800]	training's binary_logloss: 0.0844484	valid_1's binary_logloss: 0.0797352
# [801]	training's binary_logloss: 0.0844454	valid_1's binary_logloss: 0.0797387
# [802]	training's binary_logloss: 0.0844413	valid_1's binary_logloss: 0.079741
# [803]	training's binary_logloss: 0.0844378	valid_1's binary_logloss: 0.0797363
# [804]	training's binary_logloss: 0.0844348	valid_1's binary_logloss: 0.0797353
# [805]	training's binary_logloss: 0.0844344	valid_1's binary_logloss: 0.0797354
# [806]	training's binary_logloss: 0.0844326	valid_1's binary_logloss: 0.0797354
# [807]	training's binary_logloss: 0.0844294	valid_1's binary_logloss: 0.0797381
# [808]	training's binary_logloss: 0.0844291	valid_1's binary_logloss: 0.0797377
# [809]	training's binary_logloss: 0.0844262	valid_1's binary_logloss: 0.0797347
# [810]	training's binary_logloss: 0.0844243	valid_1's binary_logloss: 0.0797378
# [811]	training's binary_logloss: 0.0844228	valid_1's binary_logloss: 0.0797383
# [812]	training's binary_logloss: 0.0844208	valid_1's binary_logloss: 0.0797345
# [813]	training's binary_logloss: 0.0844178	valid_1's binary_logloss: 0.0797318
# [814]	training's binary_logloss: 0.0844151	valid_1's binary_logloss: 0.0797294
# [815]	training's binary_logloss: 0.0844126	valid_1's binary_logloss: 0.079729
# [816]	training's binary_logloss: 0.08441	valid_1's binary_logloss: 0.0797289
# [817]	training's binary_logloss: 0.0844072	valid_1's binary_logloss: 0.0797292
# [818]	training's binary_logloss: 0.0844022	valid_1's binary_logloss: 0.0797217
# [819]	training's binary_logloss: 0.0843985	valid_1's binary_logloss: 0.0797258
# [820]	training's binary_logloss: 0.0843972	valid_1's binary_logloss: 0.0797251
# [821]	training's binary_logloss: 0.0843938	valid_1's binary_logloss: 0.0797266
# [822]	training's binary_logloss: 0.0843907	valid_1's binary_logloss: 0.0797217
# [823]	training's binary_logloss: 0.0843904	valid_1's binary_logloss: 0.0797214
# [824]	training's binary_logloss: 0.0843868	valid_1's binary_logloss: 0.0797235
# [825]	training's binary_logloss: 0.0843841	valid_1's binary_logloss: 0.0797261
# [826]	training's binary_logloss: 0.084383	valid_1's binary_logloss: 0.0797264
# [827]	training's binary_logloss: 0.0843799	valid_1's binary_logloss: 0.0797285
# [828]	training's binary_logloss: 0.0843765	valid_1's binary_logloss: 0.079728
# [829]	training's binary_logloss: 0.0843743	valid_1's binary_logloss: 0.0797299
# [830]	training's binary_logloss: 0.0843732	valid_1's binary_logloss: 0.0797294
# [831]	training's binary_logloss: 0.0843706	valid_1's binary_logloss: 0.0797277
# [832]	training's binary_logloss: 0.0843694	valid_1's binary_logloss: 0.0797293
# [833]	training's binary_logloss: 0.0843645	valid_1's binary_logloss: 0.0797334
# [834]	training's binary_logloss: 0.0843596	valid_1's binary_logloss: 0.0797366
# [835]	training's binary_logloss: 0.0843567	valid_1's binary_logloss: 0.079737
# [836]	training's binary_logloss: 0.0843537	valid_1's binary_logloss: 0.0797376
# [837]	training's binary_logloss: 0.0843514	valid_1's binary_logloss: 0.0797354
# [838]	training's binary_logloss: 0.0843479	valid_1's binary_logloss: 0.0797342
# [839]	training's binary_logloss: 0.0843449	valid_1's binary_logloss: 0.0797367
# [840]	training's binary_logloss: 0.0843411	valid_1's binary_logloss: 0.0797363
# [841]	training's binary_logloss: 0.0843382	valid_1's binary_logloss: 0.0797381
# [842]	training's binary_logloss: 0.0843339	valid_1's binary_logloss: 0.0797338
# [843]	training's binary_logloss: 0.0843309	valid_1's binary_logloss: 0.0797315
# [844]	training's binary_logloss: 0.0843277	valid_1's binary_logloss: 0.0797313
# [845]	training's binary_logloss: 0.0843261	valid_1's binary_logloss: 0.0797326
# [846]	training's binary_logloss: 0.0843229	valid_1's binary_logloss: 0.0797362
# [847]	training's binary_logloss: 0.0843196	valid_1's binary_logloss: 0.0797368
# [848]	training's binary_logloss: 0.0843153	valid_1's binary_logloss: 0.07974
# [849]	training's binary_logloss: 0.0843133	valid_1's binary_logloss: 0.0797424
# [850]	training's binary_logloss: 0.0843099	valid_1's binary_logloss: 0.079741
# [851]	training's binary_logloss: 0.0843073	valid_1's binary_logloss: 0.079742
# [852]	training's binary_logloss: 0.0843042	valid_1's binary_logloss: 0.0797416
# [853]	training's binary_logloss: 0.0843013	valid_1's binary_logloss: 0.0797391
# [854]	training's binary_logloss: 0.0842951	valid_1's binary_logloss: 0.0797392
# [855]	training's binary_logloss: 0.0842916	valid_1's binary_logloss: 0.0797401
# [856]	training's binary_logloss: 0.0842904	valid_1's binary_logloss: 0.0797402
# [857]	training's binary_logloss: 0.0842879	valid_1's binary_logloss: 0.0797386
# [858]	training's binary_logloss: 0.0842852	valid_1's binary_logloss: 0.0797366
# [859]	training's binary_logloss: 0.0842829	valid_1's binary_logloss: 0.0797366
# [860]	training's binary_logloss: 0.0842822	valid_1's binary_logloss: 0.0797381
# [861]	training's binary_logloss: 0.0842792	valid_1's binary_logloss: 0.0797371
# [862]	training's binary_logloss: 0.0842753	valid_1's binary_logloss: 0.0797387
# [863]	training's binary_logloss: 0.0842716	valid_1's binary_logloss: 0.0797393
# [864]	training's binary_logloss: 0.0842672	valid_1's binary_logloss: 0.0797387
# [865]	training's binary_logloss: 0.084264	valid_1's binary_logloss: 0.079739
# [866]	training's binary_logloss: 0.0842591	valid_1's binary_logloss: 0.0797401
# [867]	training's binary_logloss: 0.0842542	valid_1's binary_logloss: 0.0797421
# [868]	training's binary_logloss: 0.0842519	valid_1's binary_logloss: 0.0797394
# [869]	training's binary_logloss: 0.0842486	valid_1's binary_logloss: 0.0797386
# [870]	training's binary_logloss: 0.0842467	valid_1's binary_logloss: 0.0797416
# [871]	training's binary_logloss: 0.0842457	valid_1's binary_logloss: 0.0797418
# [872]	training's binary_logloss: 0.0842414	valid_1's binary_logloss: 0.0797396
# [873]	training's binary_logloss: 0.0842377	valid_1's binary_logloss: 0.0797406
# [874]	training's binary_logloss: 0.084234	valid_1's binary_logloss: 0.079743
# [875]	training's binary_logloss: 0.0842296	valid_1's binary_logloss: 0.0797422
# [876]	training's binary_logloss: 0.0842263	valid_1's binary_logloss: 0.0797458
# [877]	training's binary_logloss: 0.0842247	valid_1's binary_logloss: 0.0797471
# [878]	training's binary_logloss: 0.0842239	valid_1's binary_logloss: 0.0797464
# [879]	training's binary_logloss: 0.0842213	valid_1's binary_logloss: 0.0797443
# [880]	training's binary_logloss: 0.0842205	valid_1's binary_logloss: 0.0797465
# [881]	training's binary_logloss: 0.0842196	valid_1's binary_logloss: 0.079747
# [882]	training's binary_logloss: 0.0842181	valid_1's binary_logloss: 0.079747
# [883]	training's binary_logloss: 0.0842143	valid_1's binary_logloss: 0.0797494
# [884]	training's binary_logloss: 0.0842117	valid_1's binary_logloss: 0.0797468
# [885]	training's binary_logloss: 0.0842079	valid_1's binary_logloss: 0.0797398
# [886]	training's binary_logloss: 0.0842041	valid_1's binary_logloss: 0.0797399
# [887]	training's binary_logloss: 0.0842019	valid_1's binary_logloss: 0.0797428
# [888]	training's binary_logloss: 0.0841982	valid_1's binary_logloss: 0.0797455
# [889]	training's binary_logloss: 0.0841938	valid_1's binary_logloss: 0.0797493
# [890]	training's binary_logloss: 0.0841907	valid_1's binary_logloss: 0.0797527
# [891]	training's binary_logloss: 0.0841878	valid_1's binary_logloss: 0.0797521
# [892]	training's binary_logloss: 0.0841856	valid_1's binary_logloss: 0.0797505
# [893]	training's binary_logloss: 0.0841825	valid_1's binary_logloss: 0.0797487
# [894]	training's binary_logloss: 0.0841791	valid_1's binary_logloss: 0.0797509
# [895]	training's binary_logloss: 0.0841766	valid_1's binary_logloss: 0.0797511
# [896]	training's binary_logloss: 0.0841749	valid_1's binary_logloss: 0.0797533
# [897]	training's binary_logloss: 0.08417	valid_1's binary_logloss: 0.0797533
# Early stopping, best iteration is:
# [697]	training's binary_logloss: 0.0847787	valid_1's binary_logloss: 0.0796796
# 0.07967957337583416

# %%
start_features = ['item_category_list', 'item_price_level', 'item_sales_level', 'item_collected_level', 'item_pv_level', 
                  'user_gender_id', 'user_age_level', 'user_occupation_id', 'user_star_level', 
                  'context_page_id', 'shop_review_num_level', 'shop_review_positive_rate', 
                  'shop_score_service', 'shop_score_delivery', 'hour', 'day', 'user_id_query_day_hour', 
                  'check_item_category_list_ratio', 'check_ratio_day_all', 'check_time_day', 'shop_id', 
                  'item_id_query_day', 'check_shop_id_ratio', 'user_id_query_day_item_brand_id', 
                  'user_id_query_day_hour_item_brand_id', 'check_item_brand_id_ratio', 'user_id_query_day_item_id', 
                  'user_id_query_day', 'item_brand_id',
                 ]
print(len(start_features))
clf = lgbm.LGBMClassifier(random_state=1, num_leaves = 6,
                          n_estimators=5000,max_depth=3,learning_rate = 0.08, n_jobs=30) #008154

for j in ['check_item_category_list_time_day',
       'user_id_query_day_item_pv_level',
       'user_id_query_day_hour_item_pv_level', 'check_item_pv_level_time_day',
       'check_item_pv_level_ratio', 'user_id_query_day_item_sales_level',
       'user_id_query_day_hour_item_sales_level',
       'check_item_sales_level_time_day', 'check_item_sales_level_ratio',
       'user_id_query_day_item_collected_level',
       'user_id_query_day_hour_item_collected_level',
       'check_item_collected_level_time_day',
       'check_item_collected_level_ratio',
       'user_id_query_day_item_price_level',
       'user_id_query_day_hour_item_price_level',
       'check_item_price_level_time_day', 'check_item_price_level_ratio']:
    print(j)        
    clf = run(start_features + [j], label, df, clf,False)
# Out:
# 29
# check_item_category_list_time_day
# check_item_category_list_time_day
# 0.07963547594419575
# check_item_category_list_ratio
# check_item_category_list_ratio
# 0.07953425004195597
# user_id_query_day_item_pv_level
# user_id_query_day_item_pv_level
# 0.07969346618514171
# user_id_query_day_hour_item_pv_level
# user_id_query_day_hour_item_pv_level
# 0.07963122727396559
# check_item_pv_level_time_day
# check_item_pv_level_time_day
# 0.07965062144430499
# check_item_pv_level_ratio
# check_item_pv_level_ratio
# 0.0795931804800677
# user_id_query_day_item_sales_level
# user_id_query_day_item_sales_level
# 0.07959117665153828
# user_id_query_day_hour_item_sales_level
# user_id_query_day_hour_item_sales_level
# 0.07959362835500462
# check_item_sales_level_time_day
# check_item_sales_level_time_day
# 0.07964441779301137
# check_item_sales_level_ratio
# check_item_sales_level_ratio
# 0.07965598563770808
# user_id_query_day_item_collected_level
# user_id_query_day_item_collected_level
# 0.07964523998845008
# user_id_query_day_hour_item_collected_level
# user_id_query_day_hour_item_collected_level
# 0.07962824530858356
# check_item_collected_level_time_day
# check_item_collected_level_time_day
# 0.07963185941861246
# check_item_collected_level_ratio
# check_item_collected_level_ratio
# 0.07961707720622423
# user_id_query_day_item_price_level
# user_id_query_day_item_price_level
# 0.07964775998962498
# user_id_query_day_hour_item_price_level
# user_id_query_day_hour_item_price_level
# 0.07956331555867752
# check_item_price_level_time_day
# check_item_price_level_time_day
# 0.07964697827719892
# check_item_price_level_ratio
# check_item_price_level_ratio
# 0.07967698605861155

# %% [markdown]
# best so far: 0.07962037953591194 -> 0.08154

# %%
start_features = ['item_category_list', 'item_price_level', 'item_sales_level', 'item_collected_level', 'item_pv_level', 
                  'user_gender_id', 'user_age_level', 'user_occupation_id', 'user_star_level', 
                  'context_page_id', 'shop_review_num_level', 'shop_review_positive_rate', 
                  'shop_score_service', 'shop_score_delivery', 'hour', 'day', 'user_id_query_day_hour', 
                  'check_item_category_list_ratio', 'check_ratio_day_all', 'check_time_day', 'shop_id', 
                  'item_id_query_day', 'check_shop_id_ratio', 'user_id_query_day_item_brand_id', 
                  'user_id_query_day_hour_item_brand_id', 'check_item_brand_id_ratio', 'user_id_query_day_item_id', 
                  'user_id_query_day', 'item_brand_id',
                 ]
print(len(start_features))
clf = lgbm.LGBMClassifier(random_state=1, num_leaves = 6,
                          n_estimators=5000,max_depth=3,learning_rate = 0.08, n_jobs=30) #008154
clf = run(start_features, label, df, clf,True)
# Out:
# 29
# item_brand_id
# [1]	training's binary_logloss: 0.622077	valid_1's binary_logloss: 0.621701
# Training until validation scores don't improve for 200 rounds.
# [2]	training's binary_logloss: 0.561536	valid_1's binary_logloss: 0.560814
# [3]	training's binary_logloss: 0.509395	valid_1's binary_logloss: 0.508354
# [4]	training's binary_logloss: 0.464099	valid_1's binary_logloss: 0.462754
# [5]	training's binary_logloss: 0.424476	valid_1's binary_logloss: 0.422855
# [6]	training's binary_logloss: 0.389616	valid_1's binary_logloss: 0.387733
# [7]	training's binary_logloss: 0.358798	valid_1's binary_logloss: 0.356665
# [8]	training's binary_logloss: 0.331451	valid_1's binary_logloss: 0.329077
# [9]	training's binary_logloss: 0.307103	valid_1's binary_logloss: 0.304497
# [10]	training's binary_logloss: 0.28536	valid_1's binary_logloss: 0.282525
# [11]	training's binary_logloss: 0.265903	valid_1's binary_logloss: 0.262855
# [12]	training's binary_logloss: 0.248458	valid_1's binary_logloss: 0.245197
# [13]	training's binary_logloss: 0.232786	valid_1's binary_logloss: 0.229323
# [14]	training's binary_logloss: 0.21869	valid_1's binary_logloss: 0.215037
# [15]	training's binary_logloss: 0.205998	valid_1's binary_logloss: 0.202163
# [16]	training's binary_logloss: 0.194558	valid_1's binary_logloss: 0.190541
# [17]	training's binary_logloss: 0.184242	valid_1's binary_logloss: 0.180045
# [18]	training's binary_logloss: 0.174932	valid_1's binary_logloss: 0.170565
# [19]	training's binary_logloss: 0.166527	valid_1's binary_logloss: 0.161995
# [20]	training's binary_logloss: 0.15894	valid_1's binary_logloss: 0.15424
# [21]	training's binary_logloss: 0.152082	valid_1's binary_logloss: 0.147231
# [22]	training's binary_logloss: 0.145894	valid_1's binary_logloss: 0.14088
# [23]	training's binary_logloss: 0.140304	valid_1's binary_logloss: 0.135134
# [24]	training's binary_logloss: 0.135257	valid_1's binary_logloss: 0.129938
# [25]	training's binary_logloss: 0.130697	valid_1's binary_logloss: 0.125244
# [26]	training's binary_logloss: 0.126591	valid_1's binary_logloss: 0.121005
# [27]	training's binary_logloss: 0.122884	valid_1's binary_logloss: 0.117168
# [28]	training's binary_logloss: 0.119542	valid_1's binary_logloss: 0.113694
# [29]	training's binary_logloss: 0.116533	valid_1's binary_logloss: 0.110564
# [30]	training's binary_logloss: 0.113818	valid_1's binary_logloss: 0.107733
# [31]	training's binary_logloss: 0.111378	valid_1's binary_logloss: 0.105174
# [32]	training's binary_logloss: 0.109183	valid_1's binary_logloss: 0.102859
# [33]	training's binary_logloss: 0.107214	valid_1's binary_logloss: 0.100782
# [34]	training's binary_logloss: 0.105443	valid_1's binary_logloss: 0.0989187
# [35]	training's binary_logloss: 0.103852	valid_1's binary_logloss: 0.0972186
# [36]	training's binary_logloss: 0.102429	valid_1's binary_logloss: 0.0956952
# [37]	training's binary_logloss: 0.101156	valid_1's binary_logloss: 0.094331
# [38]	training's binary_logloss: 0.0999725	valid_1's binary_logloss: 0.0930739
# [39]	training's binary_logloss: 0.0989321	valid_1's binary_logloss: 0.0919698
# [40]	training's binary_logloss: 0.0979876	valid_1's binary_logloss: 0.0909563
# [41]	training's binary_logloss: 0.0971121	valid_1's binary_logloss: 0.0900067
# [42]	training's binary_logloss: 0.0963746	valid_1's binary_logloss: 0.0891932
# [43]	training's binary_logloss: 0.0956639	valid_1's binary_logloss: 0.0884283
# [44]	training's binary_logloss: 0.0950625	valid_1's binary_logloss: 0.0877839
# [45]	training's binary_logloss: 0.0945034	valid_1's binary_logloss: 0.0871661
# [46]	training's binary_logloss: 0.0939882	valid_1's binary_logloss: 0.0866056
# [47]	training's binary_logloss: 0.0935677	valid_1's binary_logloss: 0.0861486
# [48]	training's binary_logloss: 0.093175	valid_1's binary_logloss: 0.0857143
# [49]	training's binary_logloss: 0.0928329	valid_1's binary_logloss: 0.0853281
# [50]	training's binary_logloss: 0.092501	valid_1's binary_logloss: 0.0849453
# [51]	training's binary_logloss: 0.0922154	valid_1's binary_logloss: 0.0846375
# [52]	training's binary_logloss: 0.0919275	valid_1's binary_logloss: 0.0843203
# [53]	training's binary_logloss: 0.0916844	valid_1's binary_logloss: 0.0840369
# [54]	training's binary_logloss: 0.0914845	valid_1's binary_logloss: 0.0838117
# [55]	training's binary_logloss: 0.0912776	valid_1's binary_logloss: 0.0835686
# [56]	training's binary_logloss: 0.0910792	valid_1's binary_logloss: 0.0833487
# [57]	training's binary_logloss: 0.0909234	valid_1's binary_logloss: 0.0831746
# [58]	training's binary_logloss: 0.0907837	valid_1's binary_logloss: 0.0830239
# [59]	training's binary_logloss: 0.0906258	valid_1's binary_logloss: 0.0828561
# [60]	training's binary_logloss: 0.0905089	valid_1's binary_logloss: 0.0827303
# [61]	training's binary_logloss: 0.0903772	valid_1's binary_logloss: 0.0825736
# [62]	training's binary_logloss: 0.0902684	valid_1's binary_logloss: 0.0824538
# [63]	training's binary_logloss: 0.0901748	valid_1's binary_logloss: 0.0823672
# [64]	training's binary_logloss: 0.090064	valid_1's binary_logloss: 0.0822526
# [65]	training's binary_logloss: 0.08998	valid_1's binary_logloss: 0.0821673
# [66]	training's binary_logloss: 0.0898761	valid_1's binary_logloss: 0.0820553
# [67]	training's binary_logloss: 0.0898011	valid_1's binary_logloss: 0.0819799
# [68]	training's binary_logloss: 0.0897221	valid_1's binary_logloss: 0.0819043
# [69]	training's binary_logloss: 0.0896428	valid_1's binary_logloss: 0.0818416
# [70]	training's binary_logloss: 0.0895612	valid_1's binary_logloss: 0.0817625
# [71]	training's binary_logloss: 0.0894995	valid_1's binary_logloss: 0.0816935
# [72]	training's binary_logloss: 0.0894456	valid_1's binary_logloss: 0.0816444
# [73]	training's binary_logloss: 0.0893741	valid_1's binary_logloss: 0.0815867
# [74]	training's binary_logloss: 0.0893113	valid_1's binary_logloss: 0.0815256
# [75]	training's binary_logloss: 0.0892566	valid_1's binary_logloss: 0.0814712
# [76]	training's binary_logloss: 0.0892075	valid_1's binary_logloss: 0.0814329
# [77]	training's binary_logloss: 0.0891626	valid_1's binary_logloss: 0.0813876
# [78]	training's binary_logloss: 0.0891017	valid_1's binary_logloss: 0.081328
# [79]	training's binary_logloss: 0.0890614	valid_1's binary_logloss: 0.0812974
# [80]	training's binary_logloss: 0.0889958	valid_1's binary_logloss: 0.0812435
# [81]	training's binary_logloss: 0.0889473	valid_1's binary_logloss: 0.0812051
# [82]	training's binary_logloss: 0.0889111	valid_1's binary_logloss: 0.081172
# [83]	training's binary_logloss: 0.0888607	valid_1's binary_logloss: 0.0811245
# [84]	training's binary_logloss: 0.0888241	valid_1's binary_logloss: 0.0810936
# [85]	training's binary_logloss: 0.08879	valid_1's binary_logloss: 0.0810723
# [86]	training's binary_logloss: 0.088757	valid_1's binary_logloss: 0.0810489
# [87]	training's binary_logloss: 0.0887191	valid_1's binary_logloss: 0.0810172
# [88]	training's binary_logloss: 0.0886742	valid_1's binary_logloss: 0.0809718
# [89]	training's binary_logloss: 0.0886362	valid_1's binary_logloss: 0.0809434
# [90]	training's binary_logloss: 0.0886066	valid_1's binary_logloss: 0.0809239
# [91]	training's binary_logloss: 0.0885772	valid_1's binary_logloss: 0.0808944
# [92]	training's binary_logloss: 0.0885435	valid_1's binary_logloss: 0.0808734
# [93]	training's binary_logloss: 0.0885073	valid_1's binary_logloss: 0.0808449
# [94]	training's binary_logloss: 0.088474	valid_1's binary_logloss: 0.0808205
# [95]	training's binary_logloss: 0.0884473	valid_1's binary_logloss: 0.0808091
# [96]	training's binary_logloss: 0.088417	valid_1's binary_logloss: 0.0807825
# [97]	training's binary_logloss: 0.0883846	valid_1's binary_logloss: 0.0807662
# [98]	training's binary_logloss: 0.088358	valid_1's binary_logloss: 0.080758
# [99]	training's binary_logloss: 0.0883335	valid_1's binary_logloss: 0.0807454
# [100]	training's binary_logloss: 0.0883073	valid_1's binary_logloss: 0.0807258
# [101]	training's binary_logloss: 0.0882854	valid_1's binary_logloss: 0.0807104
# [102]	training's binary_logloss: 0.0882534	valid_1's binary_logloss: 0.0806908
# [103]	training's binary_logloss: 0.0882281	valid_1's binary_logloss: 0.0806736
# [104]	training's binary_logloss: 0.0882012	valid_1's binary_logloss: 0.0806505
# [105]	training's binary_logloss: 0.0881803	valid_1's binary_logloss: 0.0806297
# [106]	training's binary_logloss: 0.0881467	valid_1's binary_logloss: 0.0806033
# [107]	training's binary_logloss: 0.0881249	valid_1's binary_logloss: 0.0805872
# [108]	training's binary_logloss: 0.0880978	valid_1's binary_logloss: 0.0805642
# [109]	training's binary_logloss: 0.0880765	valid_1's binary_logloss: 0.0805616
# [110]	training's binary_logloss: 0.0880531	valid_1's binary_logloss: 0.0805416
# [111]	training's binary_logloss: 0.0880355	valid_1's binary_logloss: 0.080529
# [112]	training's binary_logloss: 0.0880085	valid_1's binary_logloss: 0.0805074
# [113]	training's binary_logloss: 0.0879843	valid_1's binary_logloss: 0.080489
# [114]	training's binary_logloss: 0.0879623	valid_1's binary_logloss: 0.0804816
# [115]	training's binary_logloss: 0.0879419	valid_1's binary_logloss: 0.0804627
# [116]	training's binary_logloss: 0.0879262	valid_1's binary_logloss: 0.0804583
# [117]	training's binary_logloss: 0.0879047	valid_1's binary_logloss: 0.080451
# [118]	training's binary_logloss: 0.0878877	valid_1's binary_logloss: 0.0804344
# [119]	training's binary_logloss: 0.0878636	valid_1's binary_logloss: 0.0804188
# [120]	training's binary_logloss: 0.0878478	valid_1's binary_logloss: 0.0804036
# [121]	training's binary_logloss: 0.087833	valid_1's binary_logloss: 0.0803876
# [122]	training's binary_logloss: 0.0878164	valid_1's binary_logloss: 0.0803787
# [123]	training's binary_logloss: 0.0877976	valid_1's binary_logloss: 0.0803562
# [124]	training's binary_logloss: 0.0877726	valid_1's binary_logloss: 0.0803385
# [125]	training's binary_logloss: 0.0877554	valid_1's binary_logloss: 0.0803259
# [126]	training's binary_logloss: 0.0877388	valid_1's binary_logloss: 0.0803184
# [127]	training's binary_logloss: 0.0877247	valid_1's binary_logloss: 0.0803033
# [128]	training's binary_logloss: 0.0877118	valid_1's binary_logloss: 0.0802942
# [129]	training's binary_logloss: 0.0876939	valid_1's binary_logloss: 0.0802916
# [130]	training's binary_logloss: 0.0876807	valid_1's binary_logloss: 0.0802905
# [131]	training's binary_logloss: 0.0876643	valid_1's binary_logloss: 0.0802816
# [132]	training's binary_logloss: 0.0876472	valid_1's binary_logloss: 0.0802708
# [133]	training's binary_logloss: 0.0876329	valid_1's binary_logloss: 0.0802607
# [134]	training's binary_logloss: 0.087621	valid_1's binary_logloss: 0.0802641
# [135]	training's binary_logloss: 0.0876056	valid_1's binary_logloss: 0.0802606
# [136]	training's binary_logloss: 0.087585	valid_1's binary_logloss: 0.0802472
# [137]	training's binary_logloss: 0.0875738	valid_1's binary_logloss: 0.0802454
# [138]	training's binary_logloss: 0.0875603	valid_1's binary_logloss: 0.080243
# [139]	training's binary_logloss: 0.0875492	valid_1's binary_logloss: 0.0802426
# [140]	training's binary_logloss: 0.0875302	valid_1's binary_logloss: 0.0802329
# [141]	training's binary_logloss: 0.0875173	valid_1's binary_logloss: 0.0802312
# [142]	training's binary_logloss: 0.0875009	valid_1's binary_logloss: 0.0802195
# [143]	training's binary_logloss: 0.0874865	valid_1's binary_logloss: 0.0802131
# [144]	training's binary_logloss: 0.0874764	valid_1's binary_logloss: 0.0802126
# [145]	training's binary_logloss: 0.0874648	valid_1's binary_logloss: 0.0802128
# [146]	training's binary_logloss: 0.0874521	valid_1's binary_logloss: 0.0802101
# [147]	training's binary_logloss: 0.0874384	valid_1's binary_logloss: 0.0801985
# [148]	training's binary_logloss: 0.0874284	valid_1's binary_logloss: 0.0801864
# [149]	training's binary_logloss: 0.0874144	valid_1's binary_logloss: 0.0801803
# [150]	training's binary_logloss: 0.0873933	valid_1's binary_logloss: 0.0801677
# [151]	training's binary_logloss: 0.0873834	valid_1's binary_logloss: 0.0801603
# [152]	training's binary_logloss: 0.0873693	valid_1's binary_logloss: 0.0801561
# [153]	training's binary_logloss: 0.0873583	valid_1's binary_logloss: 0.0801479
# [154]	training's binary_logloss: 0.0873428	valid_1's binary_logloss: 0.0801423
# [155]	training's binary_logloss: 0.0873326	valid_1's binary_logloss: 0.0801395
# [156]	training's binary_logloss: 0.0873217	valid_1's binary_logloss: 0.0801315
# [157]	training's binary_logloss: 0.0873093	valid_1's binary_logloss: 0.0801319
# [158]	training's binary_logloss: 0.0872944	valid_1's binary_logloss: 0.0801212
# [159]	training's binary_logloss: 0.0872736	valid_1's binary_logloss: 0.0801174
# [160]	training's binary_logloss: 0.0872646	valid_1's binary_logloss: 0.0801052
# [161]	training's binary_logloss: 0.0872543	valid_1's binary_logloss: 0.0801005
# [162]	training's binary_logloss: 0.0872389	valid_1's binary_logloss: 0.0800943
# [163]	training's binary_logloss: 0.0872256	valid_1's binary_logloss: 0.080083
# [164]	training's binary_logloss: 0.0872181	valid_1's binary_logloss: 0.0800779
# [165]	training's binary_logloss: 0.0872092	valid_1's binary_logloss: 0.0800743
# [166]	training's binary_logloss: 0.0871947	valid_1's binary_logloss: 0.0800691
# [167]	training's binary_logloss: 0.0871846	valid_1's binary_logloss: 0.0800594
# [168]	training's binary_logloss: 0.0871773	valid_1's binary_logloss: 0.0800543
# [169]	training's binary_logloss: 0.0871696	valid_1's binary_logloss: 0.0800516
# [170]	training's binary_logloss: 0.0871605	valid_1's binary_logloss: 0.080053
# [171]	training's binary_logloss: 0.0871511	valid_1's binary_logloss: 0.080047
# [172]	training's binary_logloss: 0.0871397	valid_1's binary_logloss: 0.0800421
# [173]	training's binary_logloss: 0.0871304	valid_1's binary_logloss: 0.0800395
# [174]	training's binary_logloss: 0.0871182	valid_1's binary_logloss: 0.080032
# [175]	training's binary_logloss: 0.0871113	valid_1's binary_logloss: 0.0800311
# [176]	training's binary_logloss: 0.0871028	valid_1's binary_logloss: 0.0800297
# [177]	training's binary_logloss: 0.087095	valid_1's binary_logloss: 0.0800292
# [178]	training's binary_logloss: 0.0870868	valid_1's binary_logloss: 0.0800253
# [179]	training's binary_logloss: 0.0870793	valid_1's binary_logloss: 0.0800254
# [180]	training's binary_logloss: 0.0870706	valid_1's binary_logloss: 0.0800189
# [181]	training's binary_logloss: 0.0870629	valid_1's binary_logloss: 0.0800135
# [182]	training's binary_logloss: 0.0870502	valid_1's binary_logloss: 0.0800064
# [183]	training's binary_logloss: 0.0870393	valid_1's binary_logloss: 0.0799996
# [184]	training's binary_logloss: 0.0870334	valid_1's binary_logloss: 0.0800009
# [185]	training's binary_logloss: 0.0870225	valid_1's binary_logloss: 0.0799987
# [186]	training's binary_logloss: 0.0870161	valid_1's binary_logloss: 0.0799947
# [187]	training's binary_logloss: 0.0870068	valid_1's binary_logloss: 0.0799916
# [188]	training's binary_logloss: 0.0869993	valid_1's binary_logloss: 0.0799909
# [189]	training's binary_logloss: 0.0869913	valid_1's binary_logloss: 0.0799913
# [190]	training's binary_logloss: 0.0869841	valid_1's binary_logloss: 0.0799886
# [191]	training's binary_logloss: 0.0869698	valid_1's binary_logloss: 0.07999
# [192]	training's binary_logloss: 0.0869629	valid_1's binary_logloss: 0.0799905
# [193]	training's binary_logloss: 0.0869564	valid_1's binary_logloss: 0.0799831
# [194]	training's binary_logloss: 0.08695	valid_1's binary_logloss: 0.0799748
# [195]	training's binary_logloss: 0.0869413	valid_1's binary_logloss: 0.0799684
# [196]	training's binary_logloss: 0.0869361	valid_1's binary_logloss: 0.0799655
# [197]	training's binary_logloss: 0.0869254	valid_1's binary_logloss: 0.0799567
# [198]	training's binary_logloss: 0.086916	valid_1's binary_logloss: 0.0799554
# [199]	training's binary_logloss: 0.0869089	valid_1's binary_logloss: 0.0799543
# [200]	training's binary_logloss: 0.086902	valid_1's binary_logloss: 0.0799549
# [201]	training's binary_logloss: 0.0868895	valid_1's binary_logloss: 0.0799446
# [202]	training's binary_logloss: 0.0868826	valid_1's binary_logloss: 0.0799398
# [203]	training's binary_logloss: 0.086875	valid_1's binary_logloss: 0.079939
# [204]	training's binary_logloss: 0.086865	valid_1's binary_logloss: 0.0799384
# [205]	training's binary_logloss: 0.086858	valid_1's binary_logloss: 0.0799247
# [206]	training's binary_logloss: 0.0868514	valid_1's binary_logloss: 0.0799213
# [207]	training's binary_logloss: 0.0868416	valid_1's binary_logloss: 0.0799211
# [208]	training's binary_logloss: 0.0868334	valid_1's binary_logloss: 0.079917
# [209]	training's binary_logloss: 0.0868251	valid_1's binary_logloss: 0.079918
# [210]	training's binary_logloss: 0.0868167	valid_1's binary_logloss: 0.0799097
# [211]	training's binary_logloss: 0.0868053	valid_1's binary_logloss: 0.0799057
# [212]	training's binary_logloss: 0.0868003	valid_1's binary_logloss: 0.0799056
# [213]	training's binary_logloss: 0.0867946	valid_1's binary_logloss: 0.0799074
# [214]	training's binary_logloss: 0.0867852	valid_1's binary_logloss: 0.0799057
# [215]	training's binary_logloss: 0.0867798	valid_1's binary_logloss: 0.079903
# [216]	training's binary_logloss: 0.0867736	valid_1's binary_logloss: 0.0798969
# [217]	training's binary_logloss: 0.0867633	valid_1's binary_logloss: 0.079892
# [218]	training's binary_logloss: 0.0867555	valid_1's binary_logloss: 0.0798947
# [219]	training's binary_logloss: 0.0867493	valid_1's binary_logloss: 0.0798928
# [220]	training's binary_logloss: 0.0867424	valid_1's binary_logloss: 0.0798888
# [221]	training's binary_logloss: 0.0867369	valid_1's binary_logloss: 0.0798865
# [222]	training's binary_logloss: 0.0867283	valid_1's binary_logloss: 0.0798831
# [223]	training's binary_logloss: 0.0867192	valid_1's binary_logloss: 0.0798735
# [224]	training's binary_logloss: 0.086713	valid_1's binary_logloss: 0.0798671
# [225]	training's binary_logloss: 0.0867082	valid_1's binary_logloss: 0.0798626
# [226]	training's binary_logloss: 0.0867012	valid_1's binary_logloss: 0.0798613
# [227]	training's binary_logloss: 0.0866955	valid_1's binary_logloss: 0.0798583
# [228]	training's binary_logloss: 0.0866866	valid_1's binary_logloss: 0.0798557
# [229]	training's binary_logloss: 0.0866794	valid_1's binary_logloss: 0.0798541
# [230]	training's binary_logloss: 0.0866726	valid_1's binary_logloss: 0.0798556
# [231]	training's binary_logloss: 0.0866634	valid_1's binary_logloss: 0.079851
# [232]	training's binary_logloss: 0.0866583	valid_1's binary_logloss: 0.0798482
# [233]	training's binary_logloss: 0.0866538	valid_1's binary_logloss: 0.0798468
# [234]	training's binary_logloss: 0.0866494	valid_1's binary_logloss: 0.0798471
# [235]	training's binary_logloss: 0.0866422	valid_1's binary_logloss: 0.0798466
# [236]	training's binary_logloss: 0.0866338	valid_1's binary_logloss: 0.079843
# [237]	training's binary_logloss: 0.0866265	valid_1's binary_logloss: 0.0798407
# [238]	training's binary_logloss: 0.0866178	valid_1's binary_logloss: 0.0798337
# [239]	training's binary_logloss: 0.0866104	valid_1's binary_logloss: 0.0798341
# [240]	training's binary_logloss: 0.0866033	valid_1's binary_logloss: 0.0798276
# [241]	training's binary_logloss: 0.0865951	valid_1's binary_logloss: 0.0798248
# [242]	training's binary_logloss: 0.0865897	valid_1's binary_logloss: 0.0798249
# [243]	training's binary_logloss: 0.0865813	valid_1's binary_logloss: 0.0798264
# [244]	training's binary_logloss: 0.0865708	valid_1's binary_logloss: 0.079823
# [245]	training's binary_logloss: 0.0865653	valid_1's binary_logloss: 0.0798164
# [246]	training's binary_logloss: 0.0865581	valid_1's binary_logloss: 0.0798133
# [247]	training's binary_logloss: 0.0865533	valid_1's binary_logloss: 0.0798116
# [248]	training's binary_logloss: 0.086546	valid_1's binary_logloss: 0.0798092
# [249]	training's binary_logloss: 0.0865417	valid_1's binary_logloss: 0.0798109
# [250]	training's binary_logloss: 0.086538	valid_1's binary_logloss: 0.0798119
# [251]	training's binary_logloss: 0.0865337	valid_1's binary_logloss: 0.0798126
# [252]	training's binary_logloss: 0.0865266	valid_1's binary_logloss: 0.0798129
# [253]	training's binary_logloss: 0.0865198	valid_1's binary_logloss: 0.0798129
# [254]	training's binary_logloss: 0.086513	valid_1's binary_logloss: 0.0798087
# [255]	training's binary_logloss: 0.0865059	valid_1's binary_logloss: 0.079804
# [256]	training's binary_logloss: 0.0864981	valid_1's binary_logloss: 0.079804
# [257]	training's binary_logloss: 0.0864931	valid_1's binary_logloss: 0.0798005
# [258]	training's binary_logloss: 0.0864877	valid_1's binary_logloss: 0.0797964
# [259]	training's binary_logloss: 0.0864839	valid_1's binary_logloss: 0.0797949
# [260]	training's binary_logloss: 0.0864754	valid_1's binary_logloss: 0.0797893
# [261]	training's binary_logloss: 0.0864677	valid_1's binary_logloss: 0.0797752
# [262]	training's binary_logloss: 0.0864604	valid_1's binary_logloss: 0.0797688
# [263]	training's binary_logloss: 0.0864532	valid_1's binary_logloss: 0.0797704
# [264]	training's binary_logloss: 0.0864429	valid_1's binary_logloss: 0.0797694
# [265]	training's binary_logloss: 0.0864365	valid_1's binary_logloss: 0.0797729
# [266]	training's binary_logloss: 0.0864314	valid_1's binary_logloss: 0.0797692
# [267]	training's binary_logloss: 0.086425	valid_1's binary_logloss: 0.0797646
# [268]	training's binary_logloss: 0.0864216	valid_1's binary_logloss: 0.0797636
# [269]	training's binary_logloss: 0.0864153	valid_1's binary_logloss: 0.0797661
# [270]	training's binary_logloss: 0.086411	valid_1's binary_logloss: 0.0797646
# [271]	training's binary_logloss: 0.0863984	valid_1's binary_logloss: 0.0797641
# [272]	training's binary_logloss: 0.0863932	valid_1's binary_logloss: 0.0797676
# [273]	training's binary_logloss: 0.0863891	valid_1's binary_logloss: 0.079767
# [274]	training's binary_logloss: 0.0863813	valid_1's binary_logloss: 0.0797669
# [275]	training's binary_logloss: 0.0863753	valid_1's binary_logloss: 0.0797768
# [276]	training's binary_logloss: 0.0863689	valid_1's binary_logloss: 0.0797777
# [277]	training's binary_logloss: 0.0863618	valid_1's binary_logloss: 0.0797733
# [278]	training's binary_logloss: 0.0863509	valid_1's binary_logloss: 0.0797721
# [279]	training's binary_logloss: 0.0863435	valid_1's binary_logloss: 0.0797633
# [280]	training's binary_logloss: 0.0863344	valid_1's binary_logloss: 0.0797618
# [281]	training's binary_logloss: 0.0863263	valid_1's binary_logloss: 0.0797544
# [282]	training's binary_logloss: 0.0863218	valid_1's binary_logloss: 0.0797522
# [283]	training's binary_logloss: 0.0863183	valid_1's binary_logloss: 0.0797521
# [284]	training's binary_logloss: 0.0863099	valid_1's binary_logloss: 0.0797528
# [285]	training's binary_logloss: 0.0863044	valid_1's binary_logloss: 0.079753
# [286]	training's binary_logloss: 0.0862979	valid_1's binary_logloss: 0.0797439
# [287]	training's binary_logloss: 0.0862931	valid_1's binary_logloss: 0.0797421
# [288]	training's binary_logloss: 0.0862875	valid_1's binary_logloss: 0.0797406
# [289]	training's binary_logloss: 0.0862826	valid_1's binary_logloss: 0.0797451
# [290]	training's binary_logloss: 0.0862768	valid_1's binary_logloss: 0.0797467
# [291]	training's binary_logloss: 0.0862723	valid_1's binary_logloss: 0.0797455
# [292]	training's binary_logloss: 0.0862669	valid_1's binary_logloss: 0.0797471
# [293]	training's binary_logloss: 0.0862611	valid_1's binary_logloss: 0.0797497
# [294]	training's binary_logloss: 0.0862552	valid_1's binary_logloss: 0.0797443
# [295]	training's binary_logloss: 0.0862455	valid_1's binary_logloss: 0.0797354
# [296]	training's binary_logloss: 0.0862374	valid_1's binary_logloss: 0.0797333
# [297]	training's binary_logloss: 0.0862318	valid_1's binary_logloss: 0.0797305
# [298]	training's binary_logloss: 0.0862257	valid_1's binary_logloss: 0.0797306
# [299]	training's binary_logloss: 0.0862219	valid_1's binary_logloss: 0.0797277
# [300]	training's binary_logloss: 0.0862166	valid_1's binary_logloss: 0.0797284
# [301]	training's binary_logloss: 0.086212	valid_1's binary_logloss: 0.0797273
# [302]	training's binary_logloss: 0.0862083	valid_1's binary_logloss: 0.0797273
# [303]	training's binary_logloss: 0.0862012	valid_1's binary_logloss: 0.0797329
# [304]	training's binary_logloss: 0.0861962	valid_1's binary_logloss: 0.0797314
# [305]	training's binary_logloss: 0.086191	valid_1's binary_logloss: 0.0797282
# [306]	training's binary_logloss: 0.0861864	valid_1's binary_logloss: 0.0797274
# [307]	training's binary_logloss: 0.0861792	valid_1's binary_logloss: 0.0797166
# [308]	training's binary_logloss: 0.0861707	valid_1's binary_logloss: 0.0797129
# [309]	training's binary_logloss: 0.0861635	valid_1's binary_logloss: 0.0797144
# [310]	training's binary_logloss: 0.0861566	valid_1's binary_logloss: 0.0797149
# [311]	training's binary_logloss: 0.0861509	valid_1's binary_logloss: 0.0797125
# [312]	training's binary_logloss: 0.0861451	valid_1's binary_logloss: 0.0797088
# [313]	training's binary_logloss: 0.0861416	valid_1's binary_logloss: 0.0797102
# [314]	training's binary_logloss: 0.086135	valid_1's binary_logloss: 0.0797156
# [315]	training's binary_logloss: 0.0861276	valid_1's binary_logloss: 0.0797136
# [316]	training's binary_logloss: 0.0861212	valid_1's binary_logloss: 0.0797174
# [317]	training's binary_logloss: 0.0861146	valid_1's binary_logloss: 0.0797129
# [318]	training's binary_logloss: 0.0861097	valid_1's binary_logloss: 0.0797122
# [319]	training's binary_logloss: 0.0861046	valid_1's binary_logloss: 0.079714
# [320]	training's binary_logloss: 0.0861001	valid_1's binary_logloss: 0.0797124
# [321]	training's binary_logloss: 0.086096	valid_1's binary_logloss: 0.0797142
# [322]	training's binary_logloss: 0.0860885	valid_1's binary_logloss: 0.0797182
# [323]	training's binary_logloss: 0.0860818	valid_1's binary_logloss: 0.0797148
# [324]	training's binary_logloss: 0.0860767	valid_1's binary_logloss: 0.0797072
# [325]	training's binary_logloss: 0.0860709	valid_1's binary_logloss: 0.0797053
# [326]	training's binary_logloss: 0.0860653	valid_1's binary_logloss: 0.0797041
# [327]	training's binary_logloss: 0.0860604	valid_1's binary_logloss: 0.0797053
# [328]	training's binary_logloss: 0.0860547	valid_1's binary_logloss: 0.0797058
# [329]	training's binary_logloss: 0.0860519	valid_1's binary_logloss: 0.0797025
# [330]	training's binary_logloss: 0.0860462	valid_1's binary_logloss: 0.0796995
# [331]	training's binary_logloss: 0.0860405	valid_1's binary_logloss: 0.0796998
# [332]	training's binary_logloss: 0.0860344	valid_1's binary_logloss: 0.0796995
# [333]	training's binary_logloss: 0.0860296	valid_1's binary_logloss: 0.0797005
# [334]	training's binary_logloss: 0.0860258	valid_1's binary_logloss: 0.0797
# [335]	training's binary_logloss: 0.0860219	valid_1's binary_logloss: 0.0797006
# [336]	training's binary_logloss: 0.0860181	valid_1's binary_logloss: 0.0797005
# [337]	training's binary_logloss: 0.0860141	valid_1's binary_logloss: 0.0796987
# [338]	training's binary_logloss: 0.0860106	valid_1's binary_logloss: 0.0797004
# [339]	training's binary_logloss: 0.086006	valid_1's binary_logloss: 0.0796926
# [340]	training's binary_logloss: 0.0860032	valid_1's binary_logloss: 0.0796936
# [341]	training's binary_logloss: 0.0859998	valid_1's binary_logloss: 0.0796941
# [342]	training's binary_logloss: 0.085992	valid_1's binary_logloss: 0.07969
# [343]	training's binary_logloss: 0.0859877	valid_1's binary_logloss: 0.0796921
# [344]	training's binary_logloss: 0.0859774	valid_1's binary_logloss: 0.0796939
# [345]	training's binary_logloss: 0.0859744	valid_1's binary_logloss: 0.0796903
# [346]	training's binary_logloss: 0.0859683	valid_1's binary_logloss: 0.0796917
# [347]	training's binary_logloss: 0.0859617	valid_1's binary_logloss: 0.0796935
# [348]	training's binary_logloss: 0.0859566	valid_1's binary_logloss: 0.0796945
# [349]	training's binary_logloss: 0.085952	valid_1's binary_logloss: 0.0796943
# [350]	training's binary_logloss: 0.0859499	valid_1's binary_logloss: 0.0796918
# [351]	training's binary_logloss: 0.085946	valid_1's binary_logloss: 0.0796892
# [352]	training's binary_logloss: 0.0859417	valid_1's binary_logloss: 0.079692
# [353]	training's binary_logloss: 0.0859388	valid_1's binary_logloss: 0.0796928
# [354]	training's binary_logloss: 0.0859339	valid_1's binary_logloss: 0.0796941
# [355]	training's binary_logloss: 0.0859288	valid_1's binary_logloss: 0.0796955
# [356]	training's binary_logloss: 0.0859225	valid_1's binary_logloss: 0.0796928
# [357]	training's binary_logloss: 0.0859183	valid_1's binary_logloss: 0.0796902
# [358]	training's binary_logloss: 0.0859155	valid_1's binary_logloss: 0.0796895
# [359]	training's binary_logloss: 0.0859114	valid_1's binary_logloss: 0.0796883
# [360]	training's binary_logloss: 0.085902	valid_1's binary_logloss: 0.0796889
# [361]	training's binary_logloss: 0.0858948	valid_1's binary_logloss: 0.079689
# [362]	training's binary_logloss: 0.0858895	valid_1's binary_logloss: 0.0796848
# [363]	training's binary_logloss: 0.0858858	valid_1's binary_logloss: 0.079684
# [364]	training's binary_logloss: 0.085881	valid_1's binary_logloss: 0.079683
# [365]	training's binary_logloss: 0.0858774	valid_1's binary_logloss: 0.0796853
# [366]	training's binary_logloss: 0.0858714	valid_1's binary_logloss: 0.0796896
# [367]	training's binary_logloss: 0.085866	valid_1's binary_logloss: 0.0796927
# [368]	training's binary_logloss: 0.0858609	valid_1's binary_logloss: 0.0796933
# [369]	training's binary_logloss: 0.0858559	valid_1's binary_logloss: 0.0796928
# [370]	training's binary_logloss: 0.0858513	valid_1's binary_logloss: 0.0796907
# [371]	training's binary_logloss: 0.0858465	valid_1's binary_logloss: 0.0796885
# [372]	training's binary_logloss: 0.0858426	valid_1's binary_logloss: 0.079692
# [373]	training's binary_logloss: 0.0858378	valid_1's binary_logloss: 0.0796946
# [374]	training's binary_logloss: 0.0858329	valid_1's binary_logloss: 0.0796945
# [375]	training's binary_logloss: 0.0858254	valid_1's binary_logloss: 0.0796954
# [376]	training's binary_logloss: 0.0858209	valid_1's binary_logloss: 0.0796931
# [377]	training's binary_logloss: 0.0858181	valid_1's binary_logloss: 0.0796943
# [378]	training's binary_logloss: 0.0858116	valid_1's binary_logloss: 0.0796945
# [379]	training's binary_logloss: 0.0858101	valid_1's binary_logloss: 0.079695
# [380]	training's binary_logloss: 0.0858048	valid_1's binary_logloss: 0.0796952
# [381]	training's binary_logloss: 0.0858007	valid_1's binary_logloss: 0.0796956
# [382]	training's binary_logloss: 0.0857914	valid_1's binary_logloss: 0.0796931
# [383]	training's binary_logloss: 0.085786	valid_1's binary_logloss: 0.0796921
# [384]	training's binary_logloss: 0.0857816	valid_1's binary_logloss: 0.0796903
# [385]	training's binary_logloss: 0.0857752	valid_1's binary_logloss: 0.0796851
# [386]	training's binary_logloss: 0.0857707	valid_1's binary_logloss: 0.0796813
# [387]	training's binary_logloss: 0.0857643	valid_1's binary_logloss: 0.079677
# [388]	training's binary_logloss: 0.0857603	valid_1's binary_logloss: 0.0796775
# [389]	training's binary_logloss: 0.0857566	valid_1's binary_logloss: 0.0796709
# [390]	training's binary_logloss: 0.0857511	valid_1's binary_logloss: 0.0796644
# [391]	training's binary_logloss: 0.085745	valid_1's binary_logloss: 0.0796618
# [392]	training's binary_logloss: 0.0857395	valid_1's binary_logloss: 0.0796582
# [393]	training's binary_logloss: 0.0857352	valid_1's binary_logloss: 0.0796581
# [394]	training's binary_logloss: 0.0857278	valid_1's binary_logloss: 0.0796557
# [395]	training's binary_logloss: 0.0857227	valid_1's binary_logloss: 0.079657
# [396]	training's binary_logloss: 0.0857199	valid_1's binary_logloss: 0.0796578
# [397]	training's binary_logloss: 0.0857167	valid_1's binary_logloss: 0.0796573
# [398]	training's binary_logloss: 0.0857123	valid_1's binary_logloss: 0.0796604
# [399]	training's binary_logloss: 0.0857099	valid_1's binary_logloss: 0.07966
# [400]	training's binary_logloss: 0.085706	valid_1's binary_logloss: 0.0796608
# [401]	training's binary_logloss: 0.0857012	valid_1's binary_logloss: 0.0796566
# [402]	training's binary_logloss: 0.0856956	valid_1's binary_logloss: 0.0796579
# [403]	training's binary_logloss: 0.0856899	valid_1's binary_logloss: 0.0796562
# [404]	training's binary_logloss: 0.0856845	valid_1's binary_logloss: 0.0796479
# [405]	training's binary_logloss: 0.0856794	valid_1's binary_logloss: 0.0796486
# [406]	training's binary_logloss: 0.0856769	valid_1's binary_logloss: 0.0796466
# [407]	training's binary_logloss: 0.0856722	valid_1's binary_logloss: 0.0796472
# [408]	training's binary_logloss: 0.0856676	valid_1's binary_logloss: 0.0796489
# [409]	training's binary_logloss: 0.0856648	valid_1's binary_logloss: 0.0796499
# [410]	training's binary_logloss: 0.0856577	valid_1's binary_logloss: 0.0796511
# [411]	training's binary_logloss: 0.0856531	valid_1's binary_logloss: 0.0796486
# [412]	training's binary_logloss: 0.0856478	valid_1's binary_logloss: 0.0796443
# [413]	training's binary_logloss: 0.085643	valid_1's binary_logloss: 0.0796477
# [414]	training's binary_logloss: 0.0856387	valid_1's binary_logloss: 0.0796498
# [415]	training's binary_logloss: 0.0856356	valid_1's binary_logloss: 0.079651
# [416]	training's binary_logloss: 0.0856322	valid_1's binary_logloss: 0.0796547
# [417]	training's binary_logloss: 0.0856277	valid_1's binary_logloss: 0.0796497
# [418]	training's binary_logloss: 0.0856241	valid_1's binary_logloss: 0.0796465
# [419]	training's binary_logloss: 0.0856188	valid_1's binary_logloss: 0.0796449
# [420]	training's binary_logloss: 0.0856149	valid_1's binary_logloss: 0.0796453
# [421]	training's binary_logloss: 0.0856109	valid_1's binary_logloss: 0.0796441
# [422]	training's binary_logloss: 0.0856073	valid_1's binary_logloss: 0.0796445
# [423]	training's binary_logloss: 0.0855999	valid_1's binary_logloss: 0.0796416
# [424]	training's binary_logloss: 0.0855979	valid_1's binary_logloss: 0.0796404
# [425]	training's binary_logloss: 0.0855921	valid_1's binary_logloss: 0.0796424
# [426]	training's binary_logloss: 0.0855886	valid_1's binary_logloss: 0.0796382
# [427]	training's binary_logloss: 0.085584	valid_1's binary_logloss: 0.0796207
# [428]	training's binary_logloss: 0.085579	valid_1's binary_logloss: 0.0796161
# [429]	training's binary_logloss: 0.0855748	valid_1's binary_logloss: 0.0796175
# [430]	training's binary_logloss: 0.0855706	valid_1's binary_logloss: 0.0796212
# [431]	training's binary_logloss: 0.0855656	valid_1's binary_logloss: 0.0796261
# [432]	training's binary_logloss: 0.0855618	valid_1's binary_logloss: 0.0796291
# [433]	training's binary_logloss: 0.0855597	valid_1's binary_logloss: 0.079628
# [434]	training's binary_logloss: 0.0855551	valid_1's binary_logloss: 0.0796283
# [435]	training's binary_logloss: 0.0855526	valid_1's binary_logloss: 0.0796307
# [436]	training's binary_logloss: 0.0855511	valid_1's binary_logloss: 0.0796318
# [437]	training's binary_logloss: 0.0855459	valid_1's binary_logloss: 0.0796261
# [438]	training's binary_logloss: 0.0855399	valid_1's binary_logloss: 0.0796255
# [439]	training's binary_logloss: 0.0855377	valid_1's binary_logloss: 0.0796273
# [440]	training's binary_logloss: 0.0855358	valid_1's binary_logloss: 0.0796278
# [441]	training's binary_logloss: 0.0855317	valid_1's binary_logloss: 0.079633
# [442]	training's binary_logloss: 0.0855279	valid_1's binary_logloss: 0.0796332
# [443]	training's binary_logloss: 0.0855248	valid_1's binary_logloss: 0.0796336
# [444]	training's binary_logloss: 0.0855205	valid_1's binary_logloss: 0.0796329
# [445]	training's binary_logloss: 0.0855163	valid_1's binary_logloss: 0.0796352
# [446]	training's binary_logloss: 0.0855112	valid_1's binary_logloss: 0.0796331
# [447]	training's binary_logloss: 0.0855059	valid_1's binary_logloss: 0.0796221
# [448]	training's binary_logloss: 0.085501	valid_1's binary_logloss: 0.0796264
# [449]	training's binary_logloss: 0.0854975	valid_1's binary_logloss: 0.0796301
# [450]	training's binary_logloss: 0.085493	valid_1's binary_logloss: 0.0796296
# [451]	training's binary_logloss: 0.0854905	valid_1's binary_logloss: 0.0796288
# [452]	training's binary_logloss: 0.0854865	valid_1's binary_logloss: 0.0796307
# [453]	training's binary_logloss: 0.0854811	valid_1's binary_logloss: 0.0796316
# [454]	training's binary_logloss: 0.0854767	valid_1's binary_logloss: 0.0796269
# [455]	training's binary_logloss: 0.0854704	valid_1's binary_logloss: 0.079625
# [456]	training's binary_logloss: 0.0854657	valid_1's binary_logloss: 0.0796241
# [457]	training's binary_logloss: 0.0854624	valid_1's binary_logloss: 0.0796217
# [458]	training's binary_logloss: 0.085459	valid_1's binary_logloss: 0.0796218
# [459]	training's binary_logloss: 0.0854582	valid_1's binary_logloss: 0.079621
# [460]	training's binary_logloss: 0.0854564	valid_1's binary_logloss: 0.0796231
# [461]	training's binary_logloss: 0.0854541	valid_1's binary_logloss: 0.0796234
# [462]	training's binary_logloss: 0.0854491	valid_1's binary_logloss: 0.0796218
# [463]	training's binary_logloss: 0.0854431	valid_1's binary_logloss: 0.0796243
# [464]	training's binary_logloss: 0.0854382	valid_1's binary_logloss: 0.0796222
# [465]	training's binary_logloss: 0.0854316	valid_1's binary_logloss: 0.0796173
# [466]	training's binary_logloss: 0.0854283	valid_1's binary_logloss: 0.0796175
# [467]	training's binary_logloss: 0.0854244	valid_1's binary_logloss: 0.0796174
# [468]	training's binary_logloss: 0.0854211	valid_1's binary_logloss: 0.0796189
# [469]	training's binary_logloss: 0.0854161	valid_1's binary_logloss: 0.0796159
# [470]	training's binary_logloss: 0.0854138	valid_1's binary_logloss: 0.0796134
# [471]	training's binary_logloss: 0.085412	valid_1's binary_logloss: 0.0796156
# [472]	training's binary_logloss: 0.0854077	valid_1's binary_logloss: 0.0796159
# [473]	training's binary_logloss: 0.085404	valid_1's binary_logloss: 0.0796148

# %%
df.columns
# Out:
# Index(['instance_id', 'item_id', 'item_category_list', 'item_property_list',
#        'item_brand_id', 'item_city_id', 'item_price_level', 'item_sales_level',
#        'item_collected_level', 'item_pv_level', 'user_id', 'user_gender_id',
#        'user_age_level', 'user_occupation_id', 'user_star_level', 'context_id',
#        'context_timestamp', 'context_page_id', 'predict_category_property',
#        'shop_id', 'shop_review_num_level', 'shop_review_positive_rate',
#        'shop_star_level', 'shop_score_service', 'shop_score_delivery',
#        'shop_score_description', 'is_trade', 'hour', 'day',
#        'user_id_query_day', 'user_id_query_day_hour', 'item_id_query_day',
#        'item_id_query_day_hour', 'shop_id_query_day', 'shop_id_query_day_hour',
#        'item_category_list_query_day', 'item_category_list_query_day_hour',
#        'item_city_id_query_day', 'item_city_id_query_day_hour',
#        'user_gender_id_query_day', 'user_gender_id_query_day_hour',
#        'user_age_level_query_day', 'user_age_level_query_day_hour',
#        'user_occupation_id_query_day', 'user_occupation_id_query_day_hour',
#        'item_brand_id_query_day', 'item_brand_id_query_day_hour',
#        'user_id_query_day_shop_id', 'user_id_query_day_hour_shop_id',
#        'check_shop_id_time_day', 'check_shop_id_ratio',
#        'user_id_query_day_item_brand_id',
#        'user_id_query_day_hour_item_brand_id', 'check_item_brand_id_time_day',
#        'check_item_brand_id_ratio', 'user_id_query_day_item_id',
#        'user_id_query_day_hour_item_id', 'check_item_id_time_day',
#        'check_item_id_ratio', 'user_id_query_day_item_category_list',
#        'user_id_query_day_hour_item_category_list',
#        'check_item_category_list_time_day', 'check_item_category_list_ratio',
#        'user_id_query_day_context_page_id',
#        'user_id_query_day_hour_context_page_id',
#        'check_context_page_id_time_day', 'check_context_page_id_ratio',
#        'user_id_query_day_item_pv_level',
#        'user_id_query_day_hour_item_pv_level', 'check_item_pv_level_time_day',
#        'check_item_pv_level_ratio', 'user_id_query_day_item_sales_level',
#        'user_id_query_day_hour_item_sales_level',
#        'check_item_sales_level_time_day', 'check_item_sales_level_ratio',
#        'user_id_query_day_item_collected_level',
#        'user_id_query_day_hour_item_collected_level',
#        'check_item_collected_level_time_day',
#        'check_item_collected_level_ratio',
#        'user_id_query_day_item_price_level',
#        'user_id_query_day_hour_item_price_level',
#        'check_item_price_level_time_day', 'check_item_price_level_ratio',
#        'check_time_day', 'check_ratio_day_all'],
#       dtype='object')

# %%
print(len(np.unique(df.context_page_id)))
# Out:
# 20

# %%
print(len(df))
# Out:
# 478138

# %%
df.context_id[:3]
# Out:
# 0    7943330529831398173
# 1    8211008059339466280
# 2     566319850199326447
# Name: context_id, dtype: int64
